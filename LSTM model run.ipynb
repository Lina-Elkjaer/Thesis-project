# %% [markdown]
# # LSTM pipeline

# %% [markdown]
# ## Loading data

# %%
import pandas as pd
import numpy as np
import preprocessing

# %%
#loading data
df_female = pd.read_csv('data/preprocessed_data/df_female.csv', index_col=[0])
df_age = pd.read_csv('data/preprocessed_data/df_age.csv', index_col=[0])
df_SFI = pd.read_csv('data/preprocessed_data/df_SFI.csv', index_col=[0])
df_uti = pd.read_csv('data/preprocessed_data/df_uti.csv', index_col=[0])
df_admissions = pd.read_csv('data/preprocessed_data/df_admissions.csv', index_col=[0])
df_FIM_total = pd.read_csv('data/preprocessed_data/df_FIM_total.csv', index_col=[0])
df_acute_days = pd.read_csv('data/preprocessed_data/df_acute_days.csv', index_col=[0])
df_brain_injury = pd.read_csv('data/preprocessed_data/df_brain_injury.csv', index_col=[0])
df_outcome = pd.read_csv('data/preprocessed_data/df_outcome.csv', index_col=[0])

df_admissions_resampled = pd.read_csv('data/preprocessed_data/df_admissions_resampled.csv', index_col=[0])
df_SFI_resampled = pd.read_csv('test_data2/df_SFI_resampled.csv', index_col=[0])

# %%
df_age = df_age.rename(columns= {'age': 'value'})
df_female = df_female.rename(columns= {'sex': 'value'})
df_acute_days = df_acute_days.rename(columns= {' acute_days': 'value'})


df_acute_days
# Out:
#            ID  value
# 1     4361311    9.0
# 3     4384550   50.0
# 4     5008712   12.0
# 6     5314223   77.0
# 8     5771918   41.0
# ...       ...    ...
# 1853  4476147   14.0
# 1854  4732653   10.0
# 1855  4057433   48.0
# 1857  5467882   35.0
# 1863  6621963   28.0
#
# [1027 rows x 2 columns]

# %%
#Important to call predictors static, dynamic or text, otherwise they will be skipped because the function will not know how to handle them!
#Make a disclaimer message if there is such a df in the predictor dict
predictor_dict = {'df_SFI_text':df_SFI, 'df_age_static':df_age, 'df_female_static':df_female, 'df_acute_days_static':df_acute_days, 'df_FIM_total_dynamic':df_FIM_total }#, 'df_brain_injury_static':df_brain_injury}  #

predictor_dict_resampled = {'df_SFI_text':df_SFI_resampled, 'df_age_static':df_age, 'df_female_static':df_female, 'df_acute_days_static':df_acute_days, 'df_FIM_total_dynamic':df_FIM_total}#, 'df_brain_injury_static':df_brain_injury}  #

# %%
predictor_dict_train, predictor_dict_test, y_train_df, y_test_df, df_admissions_train, df_admissions_test = preprocessing.data_split(df_outcome = df_outcome, predictor_dict = predictor_dict, df_admissions = df_admissions, test_size = 0.3)

predictor_dict_train_resampled, predictor_dict_test_resampled, y_train_df_resampled, y_test_df_resampled, df_admissions_train_resampled, df_admissions_test_resampled = preprocessing.data_split(df_outcome = df_outcome, predictor_dict = predictor_dict_resampled, df_admissions = df_admissions_resampled, test_size = 0.3)
# Out:
# Number of positive observations in trainingset:224
# Percentage of positive class in trainingset: 31.197771587743734
# Number of positive observations in testset:97
# Percentage of positive class in testset: 31.3915857605178
# Number of positive observations in trainingset:224
# Percentage of positive class in trainingset: 31.197771587743734
# Number of positive observations in testset:97
# Percentage of positive class in testset: 31.3915857605178

# %% [markdown]
# ## Creating embeddings

# %% [markdown]
# ### Sentence embeddings

# %%
from sentence_embeddings import sentence_embeddings

df_sentence_train = sentence_embeddings(df_free_text = predictor_dict_train["df_SFI_text"], transformer_model = 'encoder-large-v1')
df_sentence_test = sentence_embeddings(df_free_text = predictor_dict_test["df_SFI_text"], transformer_model = 'encoder-large-v1')

df_MeDa_train = sentence_embeddings(df_free_text = predictor_dict_train["df_SFI_text"], transformer_model = 'MeDa-Bert')
df_MeDa_test = sentence_embeddings(df_free_text = predictor_dict_test["df_SFI_text"], transformer_model = 'MeDa-Bert')


#RESAMPLED
df_sentence_train_resampled = sentence_embeddings(df_free_text = predictor_dict_train_resampled["df_SFI_text"], transformer_model = 'encoder-large-v1')
df_sentence_test_resampled = sentence_embeddings(df_free_text = predictor_dict_test_resampled["df_SFI_text"], transformer_model = 'encoder-large-v1')

df_MeDa_train_resampled = sentence_embeddings(df_free_text = predictor_dict_train_resampled["df_SFI_text"], transformer_model = 'MeDa-Bert')
df_MeDa_test_resampled = sentence_embeddings(df_free_text = predictor_dict_test_resampled["df_SFI_text"], transformer_model = 'MeDa-Bert')
# Out:
# No sentence-transformers model found with name encoder-large-v1. Creating a new one with MEAN pooling.
# No sentence-transformers model found with name encoder-large-v1. Creating a new one with MEAN pooling.
# No sentence-transformers model found with name MeDa-Bert. Creating a new one with MEAN pooling.
# No sentence-transformers model found with name MeDa-Bert. Creating a new one with MEAN pooling.
# No sentence-transformers model found with name encoder-large-v1. Creating a new one with MEAN pooling.
# No sentence-transformers model found with name encoder-large-v1. Creating a new one with MEAN pooling.
# No sentence-transformers model found with name MeDa-Bert. Creating a new one with MEAN pooling.
# No sentence-transformers model found with name MeDa-Bert. Creating a new one with MEAN pooling.

# %% [markdown]
# ### TF-IDF

# %% [markdown]
# #### Hyperparametersearch

# %%
# %%capture

#Capture is important to have in this cell, otherwise there will be so much output that the kernel will crash
from tfidf_hyperparametersearch_LSTM import tfidf_hyperparametersearch

best_params = tfidf_hyperparametersearch(predictor_dict_train, 
                                            predictor_dict_test, 
                                            df_admissions_train, 
                                            df_admissions_test, 
                                            y_train_df, 
                                            y_test_df)

# %%
# %%capture

#Capture is important to have in this cell, otherwise there will be so much output that the kernel will crash
from tfidf_hyperparametersearch_LSTM import tfidf_hyperparametersearch

best_params_resampled = tfidf_hyperparametersearch(predictor_dict_train_resampled, 
                                                    predictor_dict_test_resampled, 
                                                    df_admissions_train_resampled, 
                                                    df_admissions_test_resampled, 
                                                    y_train_df_resampled, 
                                                    y_test_df_resampled,
                                                    resampled = True)
# Out:
# [I 2024-04-09 09:28:04,478] A new study created in memory with name: no-name-f3bbdae8-6cdc-4d4c-a1e9-95cbaa724fa0
# [I 2024-04-09 09:28:30,942] Trial 0 finished with value: 0.6157119237502431 and parameters: {'min_df_trial': 80, 'max_df_trial': 0.7, 'max_features_trial': 300, 'ngram_range_upper_trial': 1}. Best is trial 0 with value: 0.6157119237502431.
# [I 2024-04-09 09:28:59,119] Trial 1 finished with value: 0.6482931336315891 and parameters: {'min_df_trial': 30, 'max_df_trial': 0.6, 'max_features_trial': 400, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:29:26,556] Trial 2 finished with value: 0.613183232834079 and parameters: {'min_df_trial': 40, 'max_df_trial': 0.6, 'max_features_trial': 200, 'ngram_range_upper_trial': 1}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:29:53,777] Trial 3 finished with value: 0.6154444660571873 and parameters: {'min_df_trial': 40, 'max_df_trial': 0.8, 'max_features_trial': 500, 'ngram_range_upper_trial': 1}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:30:25,418] Trial 4 finished with value: 0.6107274849251119 and parameters: {'min_df_trial': 10, 'max_df_trial': 1.0, 'max_features_trial': 400, 'ngram_range_upper_trial': 1}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:30:54,039] Trial 5 finished with value: 0.6021688387473254 and parameters: {'min_df_trial': 20, 'max_df_trial': 0.7, 'max_features_trial': 300, 'ngram_range_upper_trial': 1}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:31:23,661] Trial 6 finished with value: 0.5980597160085587 and parameters: {'min_df_trial': 10, 'max_df_trial': 0.7, 'max_features_trial': 200, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:31:50,362] Trial 7 finished with value: 0.6127455747908968 and parameters: {'min_df_trial': 80, 'max_df_trial': 0.5, 'max_features_trial': 300, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:32:17,027] Trial 8 finished with value: 0.6217418790118654 and parameters: {'min_df_trial': 60, 'max_df_trial': 0.8, 'max_features_trial': 400, 'ngram_range_upper_trial': 1}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:32:43,403] Trial 9 finished with value: 0.6363304804512742 and parameters: {'min_df_trial': 100, 'max_df_trial': 0.9, 'max_features_trial': 400, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:33:12,106] Trial 10 finished with value: 0.6205991052324451 and parameters: {'min_df_trial': 30, 'max_df_trial': 0.5, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:33:38,488] Trial 11 finished with value: 0.6410474615833495 and parameters: {'min_df_trial': 100, 'max_df_trial': 1.0, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:34:05,369] Trial 12 finished with value: 0.6427008364131492 and parameters: {'min_df_trial': 60, 'max_df_trial': 1.0, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:34:32,125] Trial 13 finished with value: 0.6385187706671853 and parameters: {'min_df_trial': 60, 'max_df_trial': 0.6, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:34:59,564] Trial 14 finished with value: 0.6294252091032873 and parameters: {'min_df_trial': 60, 'max_df_trial': 0.9, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:35:35,181] Trial 15 finished with value: 0.6205991052324451 and parameters: {'min_df_trial': 0, 'max_df_trial': 0.6, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:36:01,828] Trial 16 finished with value: 0.618775530052519 and parameters: {'min_df_trial': 80, 'max_df_trial': 0.9, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:36:29,333] Trial 17 finished with value: 0.6360630227582182 and parameters: {'min_df_trial': 40, 'max_df_trial': 0.8, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:36:57,799] Trial 18 finished with value: 0.5921270180898657 and parameters: {'min_df_trial': 30, 'max_df_trial': 0.6, 'max_features_trial': 300, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:37:25,281] Trial 19 finished with value: 0.6219120793619919 and parameters: {'min_df_trial': 50, 'max_df_trial': 1.0, 'max_features_trial': 400, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:37:52,115] Trial 20 finished with value: 0.6191159307527718 and parameters: {'min_df_trial': 70, 'max_df_trial': 0.5, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:38:18,365] Trial 21 finished with value: 0.6273341762303053 and parameters: {'min_df_trial': 100, 'max_df_trial': 1.0, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:38:45,100] Trial 22 finished with value: 0.5792161058159891 and parameters: {'min_df_trial': 90, 'max_df_trial': 0.9, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:39:11,837] Trial 23 finished with value: 0.6267992608441938 and parameters: {'min_df_trial': 50, 'max_df_trial': 1.0, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:39:41,006] Trial 24 finished with value: 0.6137910912273876 and parameters: {'min_df_trial': 20, 'max_df_trial': 1.0, 'max_features_trial': 400, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:40:07,356] Trial 25 finished with value: 0.6481229332814629 and parameters: {'min_df_trial': 90, 'max_df_trial': 0.9, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:40:34,319] Trial 26 finished with value: 0.6365006808014004 and parameters: {'min_df_trial': 70, 'max_df_trial': 0.9, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:41:00,990] Trial 27 finished with value: 0.6292550087531609 and parameters: {'min_df_trial': 90, 'max_df_trial': 0.8, 'max_features_trial': 400, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:41:27,605] Trial 28 finished with value: 0.6236627115347209 and parameters: {'min_df_trial': 70, 'max_df_trial': 0.9, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:41:53,497] Trial 29 finished with value: 0.613183232834079 and parameters: {'min_df_trial': 90, 'max_df_trial': 0.7, 'max_features_trial': 600, 'ngram_range_upper_trial': 1}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:42:21,665] Trial 30 finished with value: 0.6071532775724567 and parameters: {'min_df_trial': 30, 'max_df_trial': 0.7, 'max_features_trial': 400, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:42:48,654] Trial 31 finished with value: 0.6191159307527718 and parameters: {'min_df_trial': 100, 'max_df_trial': 1.0, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:43:14,896] Trial 32 finished with value: 0.6358928224080918 and parameters: {'min_df_trial': 90, 'max_df_trial': 1.0, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:43:40,984] Trial 33 finished with value: 0.6224469947481035 and parameters: {'min_df_trial': 80, 'max_df_trial': 0.9, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:44:07,136] Trial 34 finished with value: 0.615979381443299 and parameters: {'min_df_trial': 100, 'max_df_trial': 1.0, 'max_features_trial': 400, 'ngram_range_upper_trial': 1}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:44:33,952] Trial 35 finished with value: 0.6438436101925695 and parameters: {'min_df_trial': 90, 'max_df_trial': 1.0, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:45:00,993] Trial 36 finished with value: 0.5849786033845555 and parameters: {'min_df_trial': 40, 'max_df_trial': 0.8, 'max_features_trial': 600, 'ngram_range_upper_trial': 1}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:45:27,187] Trial 37 finished with value: 0.6247082279712117 and parameters: {'min_df_trial': 70, 'max_df_trial': 0.9, 'max_features_trial': 200, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:45:56,260] Trial 38 finished with value: 0.607663878622836 and parameters: {'min_df_trial': 20, 'max_df_trial': 1.0, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:46:27,154] Trial 39 finished with value: 0.6224226804123711 and parameters: {'min_df_trial': 10, 'max_df_trial': 0.6, 'max_features_trial': 300, 'ngram_range_upper_trial': 1}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:46:54,110] Trial 40 finished with value: 0.6427008364131492 and parameters: {'min_df_trial': 50, 'max_df_trial': 0.7, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:47:20,975] Trial 41 finished with value: 0.6204289048823185 and parameters: {'min_df_trial': 50, 'max_df_trial': 0.7, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:47:47,880] Trial 42 finished with value: 0.6232250534915387 and parameters: {'min_df_trial': 50, 'max_df_trial': 0.7, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:48:14,400] Trial 43 finished with value: 0.6316134993191986 and parameters: {'min_df_trial': 80, 'max_df_trial': 0.8, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:48:42,370] Trial 44 finished with value: 0.5959686831355768 and parameters: {'min_df_trial': 30, 'max_df_trial': 0.5, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:49:09,101] Trial 45 finished with value: 0.6303005251896519 and parameters: {'min_df_trial': 60, 'max_df_trial': 0.6, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:49:36,479] Trial 46 finished with value: 0.6178029566232252 and parameters: {'min_df_trial': 40, 'max_df_trial': 0.8, 'max_features_trial': 400, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:50:03,333] Trial 47 finished with value: 0.6281122349737406 and parameters: {'min_df_trial': 60, 'max_df_trial': 0.7, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:50:29,706] Trial 48 finished with value: 0.6303005251896519 and parameters: {'min_df_trial': 90, 'max_df_trial': 0.9, 'max_features_trial': 600, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.
# [I 2024-04-09 09:50:55,854] Trial 49 finished with value: 0.6323186150554366 and parameters: {'min_df_trial': 80, 'max_df_trial': 0.6, 'max_features_trial': 500, 'ngram_range_upper_trial': 2}. Best is trial 1 with value: 0.6482931336315891.

# %%
best_params

# %% [markdown]
# best_params:
# {'min_df_trial': 0,
#  'max_df_trial': 1.0,
#  'max_features_trial': 200,
#  'ngram_range_upper_trial': 1}

# %%
best_params_resampled
# Out:
# {'min_df_trial': 30,
#  'max_df_trial': 0.6,
#  'max_features_trial': 400,
#  'ngram_range_upper_trial': 2}

# %% [markdown]
# best_params_resampled:
# {'min_df_trial': 30,
#  'max_df_trial': 0.6,
#  'max_features_trial': 400,
#  'ngram_range_upper_trial': 2}

# %% [markdown]
# #### Vectorizor

# %%
from tfidf import tf_idf

df_tfidfvect_train, df_tfidfvect_test = tf_idf(predictor_dict_train["df_SFI_text"], predictor_dict_test["df_SFI_text"], min_df = 0, max_df = 1.0, max_features=200, ngram_range = (1, 1))

df_tfidfvect_train_resampled, df_tfidfvect_test_resampled = tf_idf(predictor_dict_train_resampled["df_SFI_text"], predictor_dict_test_resampled["df_SFI_text"], min_df = 30, max_df = 0.6, max_features=400, ngram_range = (1, 2))
# Out:
# Tokens ['adspurgt' 'aff' 'afføring' 'aften' 'aftenvagten' 'alm' 'av' 'bad'
#  'beder' 'behandling' 'behov' 'besøg' 'ble' 'blee' 'bleen' 'bleer'
#  'bleskift' 'blevet' 'blod' 'blære' 'blæren' 'blærescannet' 'brugt'
#  'bukseble' 'bukser' 'bundskift' 'bundskifte' 'bundskiftet' 'bækken'
#  'bækkenstol' 'ca' 'dag' 'diurese' 'dv' 'efterfølgende' 'ej' 'evt'
#  'faldet' 'fik' 'fint' 'fjernet' 'forbindelse' 'forsøgt' 'fortsat'
#  'fortæller' 'fungerer' 'fået' 'får' 'føler' 'gang' 'gange' 'gerne'
#  'giver' 'givet' 'godt' 'grundet' 'gul' 'gået' 'går' 'haft' 'held' 'hele'
#  'helt' 'hjælp' 'hjælpes' 'holde' 'hvil' 'hvilket' 'ifbm' 'ifm'
#  'ildelugtende' 'inden' 'kad' 'kalder' 'kateter' 'kath' 'kl' 'klar'
#  'kolbe' 'kolben' 'komme' 'kommet' 'konc' 'koncentreret' 'kort' 'lade'
#  'lang' 'let' 'ligger' 'lys' 'læge' 'løbet' 'ml' 'morgen' 'mængde' 'mærke'
#  'mærker' 'mørk' 'nat' 'natten' 'nedre' 'nitrit' 'normal' 'nåede' 'når'
#  'obs' 'pga' 'pose' 'posen' 'positiv' 'prøve' 'pt' 'påsat' 'relevant'
#  'residualurin' 'resultat' 'ringer' 'samt' 'sat' 'scan' 'scannet' 'se'
#  'sendt' 'seng' 'sengen' 'sep' 'siddende' 'sidder' 'sidst' 'sidste'
#  'siger' 'sik' 'sikket' 'skift' 'skiftes' 'skiftet' 'slangen' 'små'
#  'spontan' 'stik' 'stikbækken' 'stix' 'stixet' 'stor' 'store' 'str'
#  'stuegang' 'stuen' 'står' 'svært' 'tage' 'tages' 'taget' 'tid' 'tilbudt'
#  'tilbydes' 'tilsyn' 'time' 'tisse' 'tisser' 'tisset' 'to' 'toilet'
#  'toiletbesøg' 'toiletstol' 'toilettet' 'trang' 'trods' 'tung' 'tøj'
#  'tømt' 'tør' 'udtryk' 'uheld' 'underlag' 'uridom' 'uridomet' 'urin'
#  'urinen' 'urinpose' 'urolig' 'ut' 'uvi' 'vagten' 'vand' 'vandet' 'vandl'
#  'vandladning' 'vandladninger' 'vandladningstrang' 'vandladningsuheld'
#  'virker' 'viser' 'vl' 'våd' 'våde' 'vådt' 'væske' 'wc' 'ønsker']
# Tokens ['aff' 'aften' 'av' 'bad' 'behov' 'ble' 'ble samt' 'ble skiftet' 'bleen'
#  'bleen våd' 'bleskift' 'blære' 'blæren' 'blærescannet' 'bukser'
#  'bundskiftet' 'bækken' 'bækkenstol' 'ca' 'ca ml' 'dag' 'dv'
#  'efterfølgende' 'evt' 'faldet' 'fik' 'fint' 'forbindelse' 'forsøgt'
#  'fortæller' 'fået' 'får' 'føler' 'gang' 'gange' 'gerne' 'givet' 'godt'
#  'gået' 'går' 'haft' 'hjælp' 'inden' 'kad' 'kalder' 'kateter' 'kl' 'klar'
#  'klar urin' 'kolbe' 'kolbe ml' 'kolben' 'komme' 'kommet' 'konc'
#  'koncentreret' 'lade' 'lade vandet' 'let' 'løbet' 'ml' 'ml klar'
#  'ml kolbe' 'ml urin' 'morgen' 'mærke' 'nat' 'natten' 'når' 'obs' 'pga'
#  'pose' 'pose tømt' 'posen' 'pt' 'påsat' 'påsat uridom' 'resultat'
#  'ringer' 'samt' 'sat' 'scannet' 'se' 'seng' 'sengen' 'sidste' 'siger'
#  'sik' 'skift' 'skift våd' 'skiftet' 'skiftet våd' 'spontan' 'stikbækken'
#  'stix' 'stor' 'stor vandl' 'stor vandladning' 'str' 'stuen' 'tages'
#  'taget' 'time' 'tisse' 'tisser' 'tisset' 'toilet' 'toiletbesøg'
#  'toilettet' 'trang' 'tung' 'tung ble' 'tung våd' 'tømt' 'tømt ml' 'tør'
#  'tør ble' 'uheld' 'uridom' 'uridom nat' 'uridom påsat' 'uridomet' 'urin'
#  'urinen' 'urinpose' 'ut' 'uvi' 'vagten' 'vandet' 'vandl' 'vandl ble'
#  'vandl bækken' 'vandl kolbe' 'vandl toilet' 'vandl toilettet'
#  'vandladning' 'vandladning ble' 'vandladning bækken'
#  'vandladning bækkenstol' 'vandladning kolbe' 'vandladning stikbækken'
#  'vandladning toilet' 'vandladning toilettet' 'vandladninger'
#  'vandladningstrang' 'vl' 'våd' 'våd ble' 'våde' 'wc' 'ønsker']

# %% [markdown]
# ## Creating tensors
#
# REMEMBER: It is possible to manually set look_back and look_ahead
#
# Look_back must be set to the same in both max_notes and tensors to create correct padding.
#
# Default settings: (look_back = 4, look_ahead = 3)

# %% [markdown]
# ## Maximum notes
#
# NB: Doesn't matter which embeddings you use. All have the same number of clinical notes.

# %% [markdown]
# #### A prediction every day

# %%
from create_tensors import max_notes, tensors
import torch

maximum_notes_train = max_notes(df_sentence_train, df_admissions_train) 
print(maximum_notes_train)

maximum_notes_test = max_notes(df_sentence_test, df_admissions_test) 
print(maximum_notes_test)

maximum_notes = max(maximum_notes_train, maximum_notes_test)
print(maximum_notes)
# Out:
# 39
# 35
# 39

# %% [markdown]
# #### One prediction per patient

# %%
from create_tensors_resampled import max_notes_resampled, tensors_resampled
import torch

#hvad hvis der er en i testsættet der har flere notes?? skal vel tjekke begge og tage den med flest??
maximum_notes_train_resampled = max_notes_resampled(df_sentence_train_resampled) 
print(maximum_notes_train_resampled)

maximum_notes_test_resampled = max_notes_resampled(df_sentence_test_resampled)
print(maximum_notes_test_resampled)

maximum_notes_resampled = max(maximum_notes_train_resampled, maximum_notes_test_resampled)
print(maximum_notes_resampled)
# Out:
# 38
# 37
# 38

# %% [markdown]
# ### Sentence Transformers

# %% [markdown]
# #### A prediction every day

# %%
############################# Ordinary sentence transformer ############################

#Train
X_sentence_train_tensor, y_sentence_train_tensor, X_structured_train_tensor, n_notes_train = tensors(df_sentence_train, y_train_df, df_admissions_train, maximum_notes, predictor_dict_train) 
torch.save(X_sentence_train_tensor, 'data/tensors/X_sentence_train_tensor_4_days.pt')
torch.save(y_sentence_train_tensor, 'data/tensors/y_sentence_train_tensor_4_days.pt')


#Test
X_sentence_test_tensor, y_sentence_test_tensor, X_structured_test_tensor, n_notes_test = tensors(df_sentence_test, y_test_df, df_admissions_test, maximum_notes, predictor_dict_test)
torch.save(X_sentence_test_tensor, 'data/tensors/X_sentence_test_tensor_4_days.pt')
torch.save(y_sentence_test_tensor, 'data/tensors/y_sentence_test_tensor_4_days.pt')




############################# MeDa-BERT sentence transformer ############################

#Train
X_MeDa_train_tensor, y_MeDa_train_tensor, X_structured_train_tensor, n_notes_train = tensors(df_MeDa_train, y_train_df, df_admissions_train, maximum_notes, predictor_dict_train) 
torch.save(X_MeDa_train_tensor, 'data/tensors/X_MeDa_train_tensor_4_days.pt')
torch.save(y_MeDa_train_tensor, 'data/tensors/y_MeDa_train_tensor_4_days.pt')


#Test
X_MeDa_test_tensor, y_MeDa_test_tensor, X_structured_test_tensor, n_notes_test = tensors(df_MeDa_test, y_test_df, df_admissions_test, maximum_notes, predictor_dict_test)
torch.save(X_MeDa_test_tensor, 'data/tensors/X_MeDa_test_tensor_4_days.pt')
torch.save(y_MeDa_test_tensor, 'data/tensors/y_MeDa_test_tensor_4_days.pt')

# %% [markdown]
# #### One prediction per patient

# %%
############################# Ordinary sentence transformer ############################

#Train
X_sentence_train_tensor_resampled, y_sentence_train_tensor_resampled, X_structured_train_tensor_resampled, n_notes_train_resampled = tensors_resampled(df_sentence_train_resampled, y_train_df_resampled, df_admissions_train_resampled, maximum_notes_resampled, predictor_dict_train_resampled) 
torch.save(X_sentence_train_tensor_resampled, 'data/tensors/X_sentence_train_tensor_4_days_resampled.pt')
torch.save(y_sentence_train_tensor_resampled, 'data/tensors/y_sentence_train_tensor_4_days_resampled.pt')


#Test
X_sentence_test_tensor_resampled, y_sentence_test_tensor_resampled, X_structured_test_tensor_resampled, n_notes_test_resampled = tensors_resampled(df_sentence_test_resampled, y_test_df_resampled, df_admissions_test_resampled, maximum_notes_resampled, predictor_dict_test_resampled) 
torch.save(X_sentence_test_tensor_resampled, 'data/tensors/X_sentence_test_tensor_4_days_resampled.pt')
torch.save(y_sentence_test_tensor_resampled, 'data/tensors/y_sentence_test_tensor_4_days_resampled.pt')




############################# MeDa-BERT sentence transformer ############################

#Train
X_MeDa_train_tensor_resampled, y_MeDa_train_tensor_resampled, X_structured_train_tensor_resampled, n_notes_train_resampled = tensors_resampled(df_MeDa_train_resampled, y_train_df_resampled, df_admissions_train_resampled, maximum_notes_resampled, predictor_dict_train_resampled) 
torch.save(X_MeDa_train_tensor_resampled, 'data/tensors/X_MeDa_train_tensor_4_days_resampled.pt')
torch.save(y_MeDa_train_tensor_resampled, 'data/tensors/y_MeDa_train_tensor_4_days_resampled.pt')


#Test
X_MeDa_test_tensor_resampled, y_MeDa_test_tensor_resampled, X_structured_test_tensor_resampled, n_notes_test_resampled = tensors_resampled(df_MeDa_test_resampled, y_test_df_resampled, df_admissions_test_resampled, maximum_notes_resampled, predictor_dict_test_resampled) 
torch.save(X_MeDa_test_tensor_resampled, 'data/tensors/X_MeDa_test_tensor_4_days_resampled.pt')
torch.save(y_MeDa_test_tensor_resampled, 'data/tensors/y_MeDa_test_tensor_4_days_resampled.pt')

# %%
df_tfidfvect_train_resampled
# Out:
#            aff     aften   av  bad  behov       ble  ble samt  ble skiftet  \
# 0     0.000000  0.000000  0.0  0.0    0.0  0.000000       0.0          0.0
# 1     0.000000  0.000000  0.0  0.0    0.0  0.000000       0.0          0.0
# 2     0.000000  0.000000  0.0  0.0    0.0  0.000000       0.0          0.0
# 3     0.000000  0.000000  0.0  0.0    0.0  0.000000       0.0          0.0
# 4     0.000000  0.000000  0.0  0.0    0.0  0.000000       0.0          0.0
# ...        ...       ...  ...  ...    ...       ...       ...          ...
# 5708  0.753397  0.000000  0.0  0.0    0.0  0.274085       0.0          0.0
# 5709  0.000000  0.000000  0.0  0.0    0.0  0.000000       0.0          0.0
# 5710  0.000000  0.000000  0.0  0.0    0.0  0.000000       0.0          0.0
# 5711  0.000000  0.000000  0.0  0.0    0.0  0.000000       0.0          0.0
# 5712  0.000000  0.368054  0.0  0.0    0.0  0.000000       0.0          0.0
#
#        bleen  bleen våd  ...  vandladninger  vandladningstrang        vl  \
# 0     0.0000        0.0  ...            0.0                0.0  0.000000
# 1     0.0000        0.0  ...            0.0                0.0  0.000000
# 2     0.0000        0.0  ...            0.0                0.0  0.000000
# 3     0.0000        0.0  ...            0.0                0.0  0.000000
# 4     0.0000        0.0  ...            0.0                0.0  0.000000
# ...      ...        ...  ...            ...                ...       ...
# 5708  0.0000        0.0  ...            0.0                0.0  0.000000
# 5709  0.0000        0.0  ...            0.0                0.0  0.000000
# 5710  0.4503        0.0  ...            0.0                0.0  0.000000
# 5711  0.0000        0.0  ...            0.0                0.0  0.000000
# 5712  0.0000        0.0  ...            0.0                0.0  0.395605
#
#            våd   våd ble  våde   wc  ønsker       ID                 date
# 0     0.000000  0.000000   0.0  0.0     0.0  5198881  2021-11-09 08:00:00
# 1     0.000000  0.000000   0.0  0.0     0.0  5198881  2021-11-09 08:00:00
# 2     0.000000  0.000000   0.0  0.0     0.0  5198881  2021-11-09 16:00:00
# 3     0.000000  0.000000   0.0  0.0     0.0  5198881  2021-11-10 09:00:00
# 4     0.000000  0.000000   0.0  0.0     0.0  5198881  2021-11-10 13:00:00
# ...        ...       ...   ...  ...     ...      ...                  ...
# 5708  0.314208  0.329108   0.0  0.0     0.0  6657351  2020-06-06 11:00:00
# 5709  1.000000  0.000000   0.0  0.0     0.0  6657351  2020-06-06 16:30:00
# 5710  0.000000  0.000000   0.0  0.0     0.0  6657351  2020-06-07 21:00:00
# 5711  0.000000  0.000000   0.0  0.0     0.0  6657351  2020-06-07 21:00:00
# 5712  0.000000  0.000000   0.0  0.0     0.0    16102  2022-01-17 23:23:00
#
# [5713 rows x 153 columns]

# %%
df_MeDa_train_resampled
# Out:
#            ID                date         0         1         2         3  \
# 0     5198881 2021-11-09 08:00:00  0.237289  0.183170  0.053262 -0.615169
# 1     5198881 2021-11-09 08:00:00  0.713899  0.413676 -0.652179 -1.086461
# 2     5198881 2021-11-09 16:00:00  0.194175 -0.130962  1.164330 -0.218816
# 3     5198881 2021-11-10 09:00:00 -0.032486 -0.030799  0.944449  0.334251
# 4     5198881 2021-11-10 13:00:00  0.163570  0.158571  0.919387  0.046360
# ...       ...                 ...       ...       ...       ...       ...
# 5708  6657351 2020-06-06 11:00:00  0.033858  0.593699  1.073424  0.078024
# 5709  6657351 2020-06-06 16:30:00 -0.707499  0.722364  0.598516 -0.035516
# 5710  6657351 2020-06-07 21:00:00 -0.574095  0.236965  0.379526  0.566196
# 5711  6657351 2020-06-07 21:00:00 -1.133537  0.424599 -0.124653  0.730124
# 5712    16102 2022-01-17 23:23:00 -0.392789  0.195305  0.911339  0.917220
#
#              4         5         6         7  ...       758       759  \
# 0     0.236463  0.262590 -0.073624  2.128982  ...  0.274637 -0.330232
# 1     0.183000  0.358287 -0.316619  1.620838  ... -0.559281 -0.282974
# 2    -0.286397 -0.396095  0.088525  1.212527  ... -0.299014  0.310303
# 3    -0.163785  0.501465 -0.090335  1.087806  ... -0.518898 -0.518911
# 4    -0.224025  0.362314 -0.167257  0.715174  ... -0.491126 -0.455356
# ...        ...       ...       ...       ...  ...       ...       ...
# 5708 -1.047423  0.371224  0.367220  1.139066  ...  0.012559  0.266149
# 5709 -0.526244  0.749863  0.249340  0.727170  ... -0.700263 -0.102425
# 5710 -0.151257 -0.045687  0.419263  0.393080  ... -0.264695  0.043642
# 5711 -0.662704 -0.700558 -0.886214  0.379581  ... -0.951335  0.037019
# 5712 -0.519240 -0.149857  0.548597  0.536164  ...  0.000472 -0.200999
#
#            760       761       762       763       764       765       766  \
# 0     0.614859 -0.548804  0.511345  0.183397 -0.399633  0.154639  0.353391
# 1     0.360609  0.193561 -0.406666  1.168989  0.120684  1.168982 -0.520272
# 2     0.490572 -0.105900 -0.145884 -0.179008 -0.435104 -0.204638  0.281645
# 3    -0.297891  0.486547  0.660673  1.479069  0.540789  0.365642  0.327292
# 4     0.034857  0.134077  0.546490  1.653240  0.589726  0.018277  0.381301
# ...        ...       ...       ...       ...       ...       ...       ...
# 5708  0.013498  0.432820 -0.039292  0.078743 -0.170353 -0.209077  0.316047
# 5709  0.409774  0.428580  0.079062  1.631156 -0.113672  0.488495  0.505197
# 5710  0.007800  0.643807 -0.380336 -0.044480 -0.346146 -0.977863 -0.388439
# 5711 -0.490757  0.219145 -0.674459  0.965008 -0.224921  0.145112  0.583543
# 5712  0.154072  0.757210 -0.131264  0.020584  0.155418 -0.678054  0.249927
#
#            767
# 0     0.393023
# 1     0.056682
# 2     0.447011
# 3     0.511015
# 4     0.560651
# ...        ...
# 5708  0.187814
# 5709  0.163490
# 5710  0.189387
# 5711  0.077202
# 5712  0.402318
#
# [5713 rows x 770 columns]

# %%
X_tfidfvect_train_tensor_resampled
# Out:
# tensor([[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         ...,
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#         [[0.0000, 0.3681, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#        device='cuda:0')

# %%
X_MeDa_train_tensor_resampled
# Out:
# tensor([[[ 2.3729e-01,  1.8317e-01,  5.3262e-02,  ...,  1.5464e-01,
#            3.5339e-01,  3.9302e-01],
#          [ 7.1390e-01,  4.1368e-01, -6.5218e-01,  ...,  1.1690e+00,
#           -5.2027e-01,  5.6682e-02],
#          [ 1.9418e-01, -1.3096e-01,  1.1643e+00,  ..., -2.0464e-01,
#            2.8164e-01,  4.4701e-01],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[-3.5995e-01, -1.2188e-01,  1.3201e+00,  ..., -3.9213e-01,
#            1.0357e+00,  4.2996e-01],
#          [-3.5995e-01, -1.2188e-01,  1.3201e+00,  ..., -3.9213e-01,
#            1.0357e+00,  4.2996e-01],
#          [-9.1122e-01,  8.4839e-01,  9.7467e-01,  ..., -1.0496e+00,
#            1.0775e+00,  7.5305e-01],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[ 5.7775e-01,  6.3136e-02, -9.9553e-01,  ...,  4.7433e-01,
#           -3.3351e-04,  7.1561e-03],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         ...,
#
#         [[ 1.0929e-01,  6.9571e-01,  1.4696e+00,  ..., -7.1361e-01,
#           -1.1589e-01,  3.4971e-01],
#          [-4.0777e-01,  2.3621e-01,  1.2422e+00,  ..., -2.0374e-01,
#           -3.2874e-02,  5.2636e-01],
#          [ 3.2186e-02,  4.4975e-01,  8.3765e-01,  ..., -2.4766e-01,
#           -2.8001e-01,  6.8842e-01],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[-2.4352e-01,  2.7827e-01,  1.0396e+00,  ...,  2.8359e-01,
#            4.0135e-01,  5.3686e-01],
#          [-1.4928e-01,  6.4804e-01,  2.3009e+00,  ..., -2.0716e-01,
#            4.8994e-01,  2.4832e-01],
#          [-4.1718e-02,  1.5296e+00,  8.7040e-01,  ...,  3.9396e-01,
#           -3.2442e-01,  4.2811e-01],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[-3.9279e-01,  1.9530e-01,  9.1134e-01,  ..., -6.7805e-01,
#            2.4993e-01,  4.0232e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]]])

# %% [markdown]
# ### TF-IDF

# %% [markdown]
# #### A prediction every day

# %%
#Train
X_tfidfvect_train_tensor, y_tfidfvect_train_tensor, X_structured_train_tensor, n_notes_train = tensors(df_tfidfvect_train, y_train_df, df_admissions_train, maximum_notes, predictor_dict_train) 
torch.save(X_tfidfvect_train_tensor, 'data/tensors/X_tfidfvect_train_tensor_4_days.pt')
torch.save(y_tfidfvect_train_tensor, 'data/tensors/y_tfidfvect_train_tensor_4_days.pt')



#Test
X_tfidfvect_test_tensor, y_tfidfvect_test_tensor, X_structured_test_tensor, n_notes_test = tensors(df_tfidfvect_test, y_test_df, df_admissions_test, maximum_notes, predictor_dict_test) 
torch.save(X_tfidfvect_test_tensor, 'data/tensors/X_tfidfvect_test_tensor_4_days.pt')
torch.save(y_tfidfvect_test_tensor, 'data/tensors/y_tfidfvect_test_tensor_4_days.pt')

# %% [markdown]
# #### One prediction per patient

# %%
#Train
X_tfidfvect_train_tensor_resampled, y_tfidfvect_train_tensor_resampled, X_structured_train_tensor_resampled, n_notes_train_resampled = tensors_resampled(df_tfidfvect_train_resampled, y_train_df_resampled, df_admissions_train_resampled, maximum_notes_resampled, predictor_dict_train_resampled) #(df_tfidfvect_train_small, y_train_df_small, df_admissions_train_small, maximum_notes, predictor_dict_train)
torch.save(X_tfidfvect_train_tensor_resampled, 'data/tensors/X_tfidfvect_train_tensor_4_days_resampled.pt')
torch.save(y_tfidfvect_train_tensor_resampled, 'data/tensors/y_tfidfvect_train_tensor_4_days_resampled.pt')


#Test
X_tfidfvect_test_tensor_resampled, y_tfidfvect_test_tensor_resampled, X_structured_test_tensor_resampled, n_notes_test_resampled = tensors_resampled(df_tfidfvect_test_resampled, y_test_df, df_admissions_test_resampled, maximum_notes_resampled, predictor_dict_test_resampled) #(df_tfidfvect_train_small, y_train_df_small, df_admissions_train_small, maximum_notes, predictor_dict_train)
torch.save(X_tfidfvect_test_tensor_resampled, 'data/tensors/X_tfidfvect_test_tensor_4_days_resampled.pt')
torch.save(y_tfidfvect_test_tensor_resampled, 'data/tensors/y_tfidfvect_test_tensor_4_days_resampled.pt')

# %% [markdown]
# NB:  N_notes and X_structured are the same for all embeddingtypes as the data has the same dimensions.
#
# Therefore, I only save once

# %%
############################ Saving n_notes tensors   ################################

########## A prediction every day
#Train
torch.save(n_notes_train, "data/tensors/n_notes_train_4_days.pt")

#Test
torch.save(n_notes_test, "data/tensors/n_notes_test_4_days.pt")


########## One prediction per patient
#Train
torch.save(n_notes_train_resampled, "data/tensors/n_notes_train_resampled.pt")

#Test
torch.save(n_notes_test_resampled, "data/tensors/n_notes_test_resampled.pt")




############################ Saving X_structured tensors   ################################

########## A prediction every day
#Train
torch.save(X_structured_train_tensor, 'data/tensors/X_structured_train_tensor_4_days.pt')

#Test
torch.save(X_structured_test_tensor, 'data/tensors/X_structured_test_tensor_4_days.pt')


########## One prediction per patient
#Train
torch.save(X_structured_train_tensor_resampled, 'data/tensors/X_structured_train_tensor_4_days_resampled.pt')

#Test
torch.save(X_structured_test_tensor_resampled, 'data/tensors/X_structured_test_tensor_4_days_resampled.pt')

# %%
#print(X_static_train_tensor.size())
#print(X_dynamic_train_tensor.size())
print(X_structured_train_tensor.size())
print(X_tfidfvect_train_tensor.size())
print(n_notes_train.size())
print(X_tfidfvect_test_tensor.size())
print(n_notes_test.size())


print(X_structured_train_tensor[0])
print(X_structured_train_tensor[1])
#[print(i) for i in n_notes_train]

#113p322665
# Out:
# torch.Size([23964, 4])
# torch.Size([23964, 39, 200])
# torch.Size([23964])
# torch.Size([9532, 39, 200])
# torch.Size([9532])
# tensor([53.,  0., 48., 33.])
# tensor([53.,  0., 48., 33.])

# %%
######################## KØR HERTIL! ###############################

# %% [markdown]
# ## Loading tensors

# %%
import torch 
import numpy as np

# %% [markdown]
# ### Sentence transformers

# %% [markdown]
# #### A prediction every day

# %%
############################# Ordinary sentence transformer ############################

#Train
X_sentence_train_tensor = torch.load("data/tensors/X_sentence_train_tensor_4_days.pt", map_location=torch.device('cuda'))
y_sentence_train_tensor = torch.load("data/tensors/y_sentence_train_tensor_4_days.pt", map_location=torch.device('cuda'))

#Test
X_sentence_test_tensor = torch.load("data/tensors/X_sentence_test_tensor_4_days.pt", map_location=torch.device('cuda'))
y_sentence_test_tensor = torch.load("data/tensors/y_sentence_test_tensor_4_days.pt", map_location=torch.device('cuda'))



############################# MeDa-BERT sentence transformer ############################

#Train
X_MeDa_train_tensor = torch.load("data/tensors/X_MeDa_train_tensor_4_days.pt", map_location=torch.device('cuda'))
y_MeDa_train_tensor = torch.load("data/tensors/y_MeDa_train_tensor_4_days.pt", map_location=torch.device('cuda'))

#Test
X_MeDa_test_tensor = torch.load("data/tensors/X_MeDa_test_tensor_4_days.pt", map_location=torch.device('cuda'))
y_MeDa_test_tensor = torch.load("data/tensors/y_MeDa_test_tensor_4_days.pt", map_location=torch.device('cuda'))

# %% [markdown]
# #### One prediction per patient

# %%
############################# Ordinary sentence transformer ############################

#Train
X_sentence_train_tensor_resampled = torch.load("data/tensors/X_sentence_train_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))
y_sentence_train_tensor_resampled = torch.load("data/tensors/y_sentence_train_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))

#Test
X_sentence_test_tensor_resampled = torch.load("data/tensors/X_sentence_test_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))
y_sentence_test_tensor_resampled = torch.load("data/tensors/y_sentence_test_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))



############################# MeDa-BERT sentence transformer ############################

#Train
X_MeDa_train_tensor_resampled = torch.load("data/tensors/X_MeDa_train_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))
y_MeDa_train_tensor_resampled = torch.load("data/tensors/y_MeDa_train_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))

#Test
X_MeDa_test_tensor_resampled = torch.load("data/tensors/X_MeDa_test_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))
y_MeDa_test_tensor_resampled = torch.load("data/tensors/y_MeDa_test_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))

# %% [markdown]
# ### TF-IDF

# %% [markdown]
# #### A prediction every day

# %%
#Train
X_tfidfvect_train_tensor = torch.load("data/tensors/X_tfidfvect_train_tensor_4_days.pt", map_location=torch.device('cuda'))
y_tfidfvect_train_tensor = torch.load("data/tensors/y_tfidfvect_train_tensor_4_days.pt", map_location=torch.device('cuda'))

#Test
X_tfidfvect_test_tensor = torch.load("data/tensors/X_tfidfvect_test_tensor_4_days.pt", map_location=torch.device('cuda'))
y_tfidfvect_test_tensor = torch.load("data/tensors/y_tfidfvect_test_tensor_4_days.pt", map_location=torch.device('cuda'))

# %% [markdown]
# #### One prediction per patient

# %%
#Train
X_tfidfvect_train_tensor_resampled = torch.load("data/tensors/X_tfidfvect_train_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))
y_tfidfvect_train_tensor_resampled = torch.load("data/tensors/y_tfidfvect_train_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))

#Test
X_tfidfvect_test_tensor_resampled = torch.load("data/tensors/X_tfidfvect_test_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))
y_tfidfvect_test_tensor_resampled = torch.load("data/tensors/y_tfidfvect_test_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))

# %%
############################ Loading n_notes tensors   ################################

########## A prediction every day
#Train
n_notes_train = torch.load("data/tensors/n_notes_train_4_days.pt", map_location=torch.device('cuda'))

#Test
n_notes_test = torch.load("data/tensors/n_notes_test_4_days.pt", map_location=torch.device('cuda'))


########## One prediction per patient
#Train
n_notes_train_resampled = torch.load("data/tensors/n_notes_train_resampled.pt", map_location=torch.device('cuda'))

#Test
n_notes_test_resampled = torch.load("data/tensors/n_notes_test_resampled.pt", map_location=torch.device('cuda'))


# ############################ Loading X_structured tensors   ################################

# ########## A prediction every day
# #Train
# X_structured_train_tensor = torch.load("data/tensors/X_structured_train_tensor_4_days.pt", map_location=torch.device('cuda'))

# #Test
# X_structured_test_tensor = torch.load("data/tensors/X_structured_test_tensor_4_days.pt", map_location=torch.device('cuda'))


# ########## One prediction per patient
# #Train
# X_structured_train_tensor_resampled = torch.load("data/tensors/X_structured_train_tensor_resampled.pt", map_location=torch.device('cuda'))

# #Test
# X_structured_test_tensor_resampled = torch.load("data/tensors/X_structured_test_tensor_4_days_resampled.pt", map_location=torch.device('cuda'))

# %% [markdown]
# ### Unsqueezing y-vectors

# %%
############################## A prediction every day ################################

####### Ordinary sentence transformer
y_sentence_train_tensor = torch.unsqueeze(y_sentence_train_tensor, 1).cuda()
y_sentence_test_tensor = torch.unsqueeze(y_sentence_test_tensor, 1).cuda()

######## MeDa-BERT sentence transformer 
y_MeDa_train_tensor = torch.unsqueeze(y_MeDa_train_tensor, 1).cuda()
y_MeDa_test_tensor = torch.unsqueeze(y_MeDa_test_tensor, 1).cuda()

######## TF-IDF
y_tfidfvect_train_tensor = torch.unsqueeze(y_tfidfvect_train_tensor, 1).cuda()
y_tfidfvect_test_tensor = torch.unsqueeze(y_tfidfvect_test_tensor, 1).cuda()


############################## One prediction per patient ################################

####### Ordinary sentence transformer
y_sentence_train_tensor_resampled = torch.unsqueeze(y_sentence_train_tensor_resampled, 1).cuda()
y_sentence_test_tensor_resampled = torch.unsqueeze(y_sentence_test_tensor_resampled, 1).cuda()

######## MeDa-BERT sentence transformer 
y_MeDa_train_tensor_resampled = torch.unsqueeze(y_MeDa_train_tensor_resampled, 1).cuda()
y_MeDa_test_tensor_resampled = torch.unsqueeze(y_MeDa_test_tensor_resampled, 1).cuda()

######## TF-IDF
y_tfidfvect_train_tensor_resampled = torch.unsqueeze(y_tfidfvect_train_tensor_resampled, 1).cuda()
y_tfidfvect_test_tensor_resampled = torch.unsqueeze(y_tfidfvect_test_tensor_resampled, 1).cuda()

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Hyperparameter search

# %%
from LSTM_hyperparametersearch import LSTM_hyperparametersearch

# %% [markdown]
# #### Sentence transformers

# %% [markdown]
# ##### A prediction every day

# %%
# %%capture

best_params_sentence = LSTM_hyperparametersearch(X_sentence_train_tensor, 
                                                y_sentence_train_tensor, 
                                                n_notes_train, 
                                                X_sentence_test_tensor, 
                                                y_sentence_test_tensor, 
                                                n_notes_test, 
                                                resampled = False)
# Out:
# [I 2024-05-07 09:53:40,548] A new study created in memory with name: no-name-a349c7a7-4806-4eb3-a123-3fab244614c1
# [I 2024-05-07 09:54:08,692] Trial 0 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 32, 'hidden_size': 96}. Best is trial 0 with value: 0.5.
# [I 2024-05-07 09:54:39,463] Trial 1 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 48}. Best is trial 0 with value: 0.5.
# [I 2024-05-07 09:55:04,545] Trial 2 finished with value: 0.5035301366872793 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 96}. Best is trial 2 with value: 0.5035301366872793.
# [I 2024-05-07 09:55:29,402] Trial 3 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 32, 'hidden_size': 48}. Best is trial 2 with value: 0.5035301366872793.
# [I 2024-05-07 09:55:55,296] Trial 4 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 32}. Best is trial 2 with value: 0.5035301366872793.
# [I 2024-05-07 09:56:21,041] Trial 5 finished with value: 0.5021233625286384 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 64}. Best is trial 2 with value: 0.5035301366872793.
# [I 2024-05-07 09:56:46,156] Trial 6 finished with value: 0.5066551239043393 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 6 with value: 0.5066551239043393.
# [I 2024-05-07 09:57:30,329] Trial 7 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 16, 'hidden_size': 80}. Best is trial 6 with value: 0.5066551239043393.
# [I 2024-05-07 09:58:01,627] Trial 8 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 96}. Best is trial 6 with value: 0.5066551239043393.
# [I 2024-05-07 09:58:26,492] Trial 9 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 32, 'hidden_size': 32}. Best is trial 6 with value: 0.5066551239043393.
# [I 2024-05-07 09:58:51,992] Trial 10 finished with value: 0.5 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 128}. Best is trial 6 with value: 0.5066551239043393.
# [I 2024-05-07 09:59:23,013] Trial 11 finished with value: 0.507313700968826 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 11 with value: 0.507313700968826.
# [I 2024-05-07 09:59:54,281] Trial 12 finished with value: 0.515304386435618 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 12 with value: 0.515304386435618.
# [I 2024-05-07 10:00:25,486] Trial 13 finished with value: 0.5144860923473048 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 12 with value: 0.515304386435618.
# [I 2024-05-07 10:01:18,838] Trial 14 finished with value: 0.5 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 12 with value: 0.515304386435618.
# [I 2024-05-07 10:01:49,940] Trial 15 finished with value: 0.523040342772442 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:02:15,231] Trial 16 finished with value: 0.5047613894600151 and parameters: {'learning_rate': 0.0001, 'batch_size': 48, 'hidden_size': 112}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:02:46,079] Trial 17 finished with value: 0.5167704734354703 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:04:00,104] Trial 18 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 112}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:04:25,374] Trial 19 finished with value: 0.5 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 112}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:04:55,392] Trial 20 finished with value: 0.5104003858495552 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 80}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:05:26,408] Trial 21 finished with value: 0.5217259776485415 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:05:57,100] Trial 22 finished with value: 0.515115663759036 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:06:27,990] Trial 23 finished with value: 0.5102882678456349 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:06:58,186] Trial 24 finished with value: 0.5125237483781936 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 96}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:07:29,110] Trial 25 finished with value: 0.5129539988940666 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:07:54,724] Trial 26 finished with value: 0.5055175817020443 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 112}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:08:25,598] Trial 27 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 128}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:08:50,783] Trial 28 finished with value: 0.5 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 112}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:09:15,874] Trial 29 finished with value: 0.508547556812963 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 96}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:10:00,436] Trial 30 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 16, 'hidden_size': 96}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:10:31,590] Trial 31 finished with value: 0.5228436249479851 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:11:02,463] Trial 32 finished with value: 0.5145349929029118 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:11:33,456] Trial 33 finished with value: 0.5206120490225281 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:11:59,195] Trial 34 finished with value: 0.5077913645709339 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 128}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:12:29,100] Trial 35 finished with value: 0.5078454712693432 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 64}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:12:54,866] Trial 36 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 128}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:13:20,407] Trial 37 finished with value: 0.5091691330768192 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 112}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:14:21,785] Trial 38 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 64, 'hidden_size': 64}. Best is trial 15 with value: 0.523040342772442.
# [I 2024-05-07 10:14:52,964] Trial 39 finished with value: 0.5317608178999089 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 39 with value: 0.5317608178999089.
# [I 2024-05-07 10:15:18,134] Trial 40 finished with value: 0.503190993670446 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 96}. Best is trial 39 with value: 0.5317608178999089.
# [I 2024-05-07 10:15:49,339] Trial 41 finished with value: 0.5083523264578781 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 39 with value: 0.5317608178999089.
# [I 2024-05-07 10:16:20,828] Trial 42 finished with value: 0.5164735373620697 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 39 with value: 0.5317608178999089.
# [I 2024-05-07 10:16:52,032] Trial 43 finished with value: 0.5218935038865715 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 39 with value: 0.5317608178999089.
# [I 2024-05-07 10:17:23,129] Trial 44 finished with value: 0.5133762542620646 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 39 with value: 0.5317608178999089.
# [I 2024-05-07 10:17:53,236] Trial 45 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 16, 'hidden_size': 48}. Best is trial 39 with value: 0.5317608178999089.
# [I 2024-05-07 10:18:24,733] Trial 46 finished with value: 0.5145666016270684 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 39 with value: 0.5317608178999089.
# [I 2024-05-07 10:18:50,583] Trial 47 finished with value: 0.5 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 128}. Best is trial 39 with value: 0.5317608178999089.
# [I 2024-05-07 10:19:20,699] Trial 48 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 32}. Best is trial 39 with value: 0.5317608178999089.
# [I 2024-05-07 10:19:46,768] Trial 49 finished with value: 0.5034628286981928 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 112}. Best is trial 39 with value: 0.5317608178999089.

# %% [markdown]
# ## IF THAT ^^ WORKS remember to implement early stopping in the rest of the LSTM functions...

# %%
best_params_sentence
# Out:
# {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}

# %%
# %%capture

best_params_MeDa = LSTM_hyperparametersearch(X_MeDa_train_tensor, 
                                            y_MeDa_train_tensor, 
                                            n_notes_train, 
                                            X_MeDa_test_tensor, 
                                            y_MeDa_test_tensor, 
                                            n_notes_test, 
                                            resampled = False)
# Out:
# [I 2024-05-07 10:19:47,214] A new study created in memory with name: no-name-ddf0e6a5-a2d2-4105-af77-8b6ca8baf89f
# [I 2024-05-07 10:20:12,530] Trial 0 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 32, 'hidden_size': 96}. Best is trial 0 with value: 0.5.
# [I 2024-05-07 10:20:37,904] Trial 1 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 128}. Best is trial 0 with value: 0.5.
# [I 2024-05-07 10:21:40,245] Trial 2 finished with value: 0.5007574937777297 and parameters: {'learning_rate': 0.1, 'batch_size': 64, 'hidden_size': 96}. Best is trial 2 with value: 0.5007574937777297.
# [I 2024-05-07 10:22:39,787] Trial 3 finished with value: 0.5804611229426904 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 48}. Best is trial 3 with value: 0.5804611229426904.
# [I 2024-05-07 10:23:11,362] Trial 4 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 48}. Best is trial 3 with value: 0.5804611229426904.
# [I 2024-05-07 10:24:26,413] Trial 5 finished with value: 0.5984524368652921 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 5 with value: 0.5984524368652921.
# [I 2024-05-07 10:25:26,780] Trial 6 finished with value: 0.6010586691388409 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 6 with value: 0.6010586691388409.
# [I 2024-05-07 10:26:09,392] Trial 7 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 48, 'hidden_size': 96}. Best is trial 6 with value: 0.6010586691388409.
# [I 2024-05-07 10:26:53,330] Trial 8 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 48}. Best is trial 6 with value: 0.6010586691388409.
# [I 2024-05-07 10:27:53,387] Trial 9 finished with value: 0.5733917388182278 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 32}. Best is trial 6 with value: 0.6010586691388409.
# [I 2024-05-07 10:28:53,814] Trial 10 finished with value: 0.6052895898340394 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 10 with value: 0.6052895898340394.
# [I 2024-05-07 10:29:54,588] Trial 11 finished with value: 0.5894140151595441 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 10 with value: 0.6052895898340394.
# [I 2024-05-07 10:30:55,082] Trial 12 finished with value: 0.6131997660210677 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:31:25,250] Trial 13 finished with value: 0.5480694320953498 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 64}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:31:50,895] Trial 14 finished with value: 0.5304741568930632 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 112}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:32:50,338] Trial 15 finished with value: 0.594874515224435 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 64}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:34:03,021] Trial 16 finished with value: 0.5964227849070945 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 64}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:35:04,269] Trial 17 finished with value: 0.5950950325588453 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 112}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:35:29,048] Trial 18 finished with value: 0.5124657370726826 and parameters: {'learning_rate': 0.0001, 'batch_size': 48, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:36:41,430] Trial 19 finished with value: 0.6059427748220523 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:37:55,762] Trial 20 finished with value: 0.5793936777345544 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:38:54,353] Trial 21 finished with value: 0.5949379186064196 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:39:54,384] Trial 22 finished with value: 0.6078575197712569 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 64}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:40:54,347] Trial 23 finished with value: 0.5608839807357842 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 64}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:42:06,241] Trial 24 finished with value: 0.6064072371334829 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 32}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:43:06,372] Trial 25 finished with value: 0.5817280749803561 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 32}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:43:36,166] Trial 26 finished with value: 0.5194706022131312 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 32}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:44:18,627] Trial 27 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 48}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:44:43,269] Trial 28 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 48, 'hidden_size': 32}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:45:13,492] Trial 29 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 16, 'hidden_size': 96}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:46:14,742] Trial 30 finished with value: 0.5912982669866214 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 64}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:47:27,588] Trial 31 finished with value: 0.5971339812006183 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 96}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:48:18,924] Trial 32 finished with value: 0.5981473197103451 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:49:18,948] Trial 33 finished with value: 0.5844137009316392 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 64}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:50:30,750] Trial 34 finished with value: 0.5975456383493404 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 48}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:51:01,783] Trial 35 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 96}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:52:14,397] Trial 36 finished with value: 0.6032850389214954 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:52:39,351] Trial 37 finished with value: 0.5007574937777297 and parameters: {'learning_rate': 0.1, 'batch_size': 48, 'hidden_size': 48}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:53:52,543] Trial 38 finished with value: 0.6046799133251596 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 64}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:54:17,721] Trial 39 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 48}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:54:42,724] Trial 40 finished with value: 0.5282200829933537 and parameters: {'learning_rate': 0.0001, 'batch_size': 48, 'hidden_size': 96}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:55:43,290] Trial 41 finished with value: 0.5799663534428036 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:56:43,596] Trial 42 finished with value: 0.5747062898758 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:57:45,021] Trial 43 finished with value: 0.6047814331098039 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:58:45,682] Trial 44 finished with value: 0.5913841683428587 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 96}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 10:59:45,881] Trial 45 finished with value: 0.6042444566664844 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 11:00:47,756] Trial 46 finished with value: 0.5968013458622878 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 128}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 11:02:00,509] Trial 47 finished with value: 0.6023743357984419 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 64}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 11:02:37,787] Trial 48 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 16, 'hidden_size': 80}. Best is trial 12 with value: 0.6131997660210677.
# [I 2024-05-07 11:03:36,993] Trial 49 finished with value: 0.5655408754724109 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 64}. Best is trial 12 with value: 0.6131997660210677.

# %%
best_params_MeDa
# Out:
# {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}

# %% [markdown]
# ##### One prediction per patient

# %%
# %%capture

best_params_sentence_resampled = LSTM_hyperparametersearch(X_sentence_train_tensor_resampled, 
                                                        y_sentence_train_tensor_resampled, 
                                                        n_notes_train_resampled, 
                                                        X_sentence_test_tensor_resampled, 
                                                        y_sentence_test_tensor_resampled, 
                                                        n_notes_test_resampled, 
                                                        resampled = True)
# Out:
# [I 2024-05-07 11:03:37,659] A new study created in memory with name: no-name-b889e567-e793-40b0-8a1a-7e81931a5387
# [I 2024-05-07 11:03:39,591] Trial 0 finished with value: 0.538246450106983 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 0 with value: 0.538246450106983.
# [I 2024-05-07 11:03:41,580] Trial 1 finished with value: 0.5546586267263178 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 32}. Best is trial 1 with value: 0.5546586267263178.
# [I 2024-05-07 11:03:42,776] Trial 2 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 64, 'hidden_size': 96}. Best is trial 1 with value: 0.5546586267263178.
# [I 2024-05-07 11:03:43,571] Trial 3 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 64}. Best is trial 1 with value: 0.5546586267263178.
# [I 2024-05-07 11:03:45,516] Trial 4 finished with value: 0.5023584905660378 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 1 with value: 0.5546586267263178.
# [I 2024-05-07 11:03:46,676] Trial 5 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 32, 'hidden_size': 32}. Best is trial 1 with value: 0.5546586267263178.
# [I 2024-05-07 11:03:48,219] Trial 6 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 32, 'hidden_size': 96}. Best is trial 1 with value: 0.5546586267263178.
# [I 2024-05-07 11:03:50,118] Trial 7 finished with value: 0.6303005251896519 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:03:52,361] Trial 8 finished with value: 0.5407751410231472 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 64}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:03:54,328] Trial 9 finished with value: 0.6006856642676521 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:03:55,782] Trial 10 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 128}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:03:57,717] Trial 11 finished with value: 0.595360824742268 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 112}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:03:59,613] Trial 12 finished with value: 0.5933427348764833 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 64}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:01,516] Trial 13 finished with value: 0.585221746741879 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 48}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:03,420] Trial 14 finished with value: 0.5905465862672632 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:05,753] Trial 15 finished with value: 0.5910815016533748 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:07,728] Trial 16 finished with value: 0.6062779614860923 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:09,069] Trial 17 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 48}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:11,030] Trial 18 finished with value: 0.521809959151916 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 112}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:13,308] Trial 19 finished with value: 0.5514248200739156 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 48}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:15,324] Trial 20 finished with value: 0.6130859754911496 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:17,290] Trial 21 finished with value: 0.5886257537444077 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:19,257] Trial 22 finished with value: 0.5749124683913636 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:21,145] Trial 23 finished with value: 0.5924674187901187 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 64}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:23,101] Trial 24 finished with value: 0.5681044543863061 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:24,990] Trial 25 finished with value: 0.5779760746936393 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:26,929] Trial 26 finished with value: 0.5024314335732348 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 64}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:27,950] Trial 27 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:28,950] Trial 28 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 48, 'hidden_size': 128}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:31,020] Trial 29 finished with value: 0.5538805679828827 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:32,990] Trial 30 finished with value: 0.6071532775724567 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:34,952] Trial 31 finished with value: 0.5850515463917525 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:36,925] Trial 32 finished with value: 0.5971843999221941 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 112}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:38,885] Trial 33 finished with value: 0.5591081501653374 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:40,846] Trial 34 finished with value: 0.5988377747519937 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:42,806] Trial 35 finished with value: 0.5983271737016145 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 64}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:43,827] Trial 36 finished with value: 0.5616611554172339 and parameters: {'learning_rate': 0.1, 'batch_size': 64, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:45,709] Trial 37 finished with value: 0.4948453608247423 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:47,642] Trial 38 finished with value: 0.605135187706672 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:48,470] Trial 39 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 64, 'hidden_size': 64}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:50,389] Trial 40 finished with value: 0.5514248200739156 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:52,336] Trial 41 finished with value: 0.607663878622836 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:54,296] Trial 42 finished with value: 0.5817204823964209 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 112}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:56,233] Trial 43 finished with value: 0.5839087726123323 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:04:58,094] Trial 44 finished with value: 0.576760357907022 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:05:00,020] Trial 45 finished with value: 0.5804075082668742 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:05:01,923] Trial 46 finished with value: 0.5898414705310251 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 96}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:05:03,905] Trial 47 finished with value: 0.5452246644621669 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 112}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:05:05,455] Trial 48 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 64}. Best is trial 7 with value: 0.6303005251896519.
# [I 2024-05-07 11:05:07,367] Trial 49 finished with value: 0.6129157751410231 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 7 with value: 0.6303005251896519.

# %%
best_params_sentence_resampled
#old {'num_epochs': 30, 'learning_rate': 0.001, 'batch_size': 32}
#new {'num_epochs': 10, 'learning_rate': 0.001, 'batch_size': 16}
# Out:
# {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}

# %%
X_MeDa_train_tensor.shape[2]
X_MeDa_train_tensor_resampled

#X_tfidfvect_train_tensor_resampled.shape[2]
# Out:
# tensor([[[ 2.3729e-01,  1.8317e-01,  5.3262e-02,  ...,  1.5464e-01,
#            3.5339e-01,  3.9302e-01],
#          [ 7.1390e-01,  4.1368e-01, -6.5218e-01,  ...,  1.1690e+00,
#           -5.2027e-01,  5.6682e-02],
#          [ 1.9418e-01, -1.3096e-01,  1.1643e+00,  ..., -2.0464e-01,
#            2.8164e-01,  4.4701e-01],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[-3.5995e-01, -1.2188e-01,  1.3201e+00,  ..., -3.9213e-01,
#            1.0357e+00,  4.2996e-01],
#          [-3.5995e-01, -1.2188e-01,  1.3201e+00,  ..., -3.9213e-01,
#            1.0357e+00,  4.2996e-01],
#          [-9.1122e-01,  8.4839e-01,  9.7467e-01,  ..., -1.0496e+00,
#            1.0775e+00,  7.5305e-01],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[ 5.7775e-01,  6.3136e-02, -9.9553e-01,  ...,  4.7433e-01,
#           -3.3351e-04,  7.1561e-03],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         ...,
#
#         [[ 1.0929e-01,  6.9571e-01,  1.4696e+00,  ..., -7.1361e-01,
#           -1.1589e-01,  3.4971e-01],
#          [-4.0777e-01,  2.3621e-01,  1.2422e+00,  ..., -2.0374e-01,
#           -3.2874e-02,  5.2636e-01],
#          [ 3.2186e-02,  4.4975e-01,  8.3765e-01,  ..., -2.4766e-01,
#           -2.8001e-01,  6.8842e-01],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[-2.4352e-01,  2.7827e-01,  1.0396e+00,  ...,  2.8359e-01,
#            4.0135e-01,  5.3686e-01],
#          [-1.4928e-01,  6.4804e-01,  2.3009e+00,  ..., -2.0716e-01,
#            4.8994e-01,  2.4832e-01],
#          [-4.1718e-02,  1.5296e+00,  8.7040e-01,  ...,  3.9396e-01,
#           -3.2442e-01,  4.2811e-01],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]],
#
#         [[-3.9279e-01,  1.9530e-01,  9.1134e-01,  ..., -6.7805e-01,
#            2.4993e-01,  4.0232e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          ...,
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#            0.0000e+00,  0.0000e+00]]], device='cuda:0')

# %%
# %%capture

best_params_MeDa_resampled = LSTM_hyperparametersearch(X_MeDa_train_tensor_resampled, 
                                                    y_MeDa_train_tensor_resampled, 
                                                    n_notes_train_resampled, 
                                                    X_MeDa_test_tensor_resampled, 
                                                    y_MeDa_test_tensor_resampled, 
                                                    n_notes_test_resampled, 
                                                    resampled = True)
# Out:
# [I 2024-05-07 11:05:07,923] A new study created in memory with name: no-name-81cdb9f9-24ce-4b8c-881b-311a9270a251
# [I 2024-05-07 11:05:09,081] Trial 0 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 16, 'hidden_size': 48}. Best is trial 0 with value: 0.5.
# [I 2024-05-07 11:05:10,475] Trial 1 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 64, 'hidden_size': 112}. Best is trial 0 with value: 0.5.
# [I 2024-05-07 11:05:12,381] Trial 2 finished with value: 0.564603190040848 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 64}. Best is trial 2 with value: 0.564603190040848.
# [I 2024-05-07 11:05:14,731] Trial 3 finished with value: 0.6130859754911496 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 3 with value: 0.6130859754911496.
# [I 2024-05-07 11:05:16,613] Trial 4 finished with value: 0.501045516436491 and parameters: {'learning_rate': 0.0001, 'batch_size': 48, 'hidden_size': 80}. Best is trial 3 with value: 0.6130859754911496.
# [I 2024-05-07 11:05:18,493] Trial 5 finished with value: 0.4948453608247423 and parameters: {'learning_rate': 0.0001, 'batch_size': 48, 'hidden_size': 80}. Best is trial 3 with value: 0.6130859754911496.
# [I 2024-05-07 11:05:20,496] Trial 6 finished with value: 0.5960416261427737 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 112}. Best is trial 3 with value: 0.6130859754911496.
# [I 2024-05-07 11:05:22,375] Trial 7 finished with value: 0.5688095701225442 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 80}. Best is trial 3 with value: 0.6130859754911496.
# [I 2024-05-07 11:05:24,614] Trial 8 finished with value: 0.5966494845360825 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 32}. Best is trial 3 with value: 0.6130859754911496.
# [I 2024-05-07 11:05:25,977] Trial 9 finished with value: 0.5070754716981132 and parameters: {'learning_rate': 0.1, 'batch_size': 32, 'hidden_size': 64}. Best is trial 3 with value: 0.6130859754911496.
# [I 2024-05-07 11:05:28,351] Trial 10 finished with value: 0.6273341762303053 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:30,742] Trial 11 finished with value: 0.5998103481812876 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:33,144] Trial 12 finished with value: 0.6072262205796537 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:35,109] Trial 13 finished with value: 0.5602509239447578 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 112}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:36,776] Trial 14 finished with value: 0.6151040653569345 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 128}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:38,341] Trial 15 finished with value: 0.5437414899824937 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 96}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:40,305] Trial 16 finished with value: 0.5919325034040069 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 96}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:41,719] Trial 17 finished with value: 0.5565065162419762 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 96}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:43,686] Trial 18 finished with value: 0.6040896712701809 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 128}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:46,016] Trial 19 finished with value: 0.5834954289048824 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 112}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:47,988] Trial 20 finished with value: 0.5606885819879401 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 112}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:50,353] Trial 21 finished with value: 0.6219120793619919 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 10 with value: 0.6273341762303053.
# [I 2024-05-07 11:05:52,703] Trial 22 finished with value: 0.6295954094534137 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:05:55,057] Trial 23 finished with value: 0.599275432795176 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:05:57,380] Trial 24 finished with value: 0.6008558646177786 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:05:59,313] Trial 25 finished with value: 0.5384166504571095 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 96}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:01,701] Trial 26 finished with value: 0.6150068080140051 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:03,746] Trial 27 finished with value: 0.5626094145107955 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 112}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:06,130] Trial 28 finished with value: 0.6061807041431628 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:07,322] Trial 29 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 16, 'hidden_size': 96}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:09,601] Trial 30 finished with value: 0.5574547753355379 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 48}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:11,520] Trial 31 finished with value: 0.570535887959541 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:12,868] Trial 32 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 16, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:15,226] Trial 33 finished with value: 0.5758607274849252 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:17,188] Trial 34 finished with value: 0.5882853530441549 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:18,598] Trial 35 finished with value: 0.5070754716981132 and parameters: {'learning_rate': 0.1, 'batch_size': 64, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:20,977] Trial 36 finished with value: 0.5905465862672632 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:22,422] Trial 37 finished with value: 0.568371912079362 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 112}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:24,395] Trial 38 finished with value: 0.5625121571678661 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:26,654] Trial 39 finished with value: 0.5044495234390197 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 32}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:28,547] Trial 40 finished with value: 0.5012157167866174 and parameters: {'learning_rate': 0.0001, 'batch_size': 48, 'hidden_size': 80}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:30,915] Trial 41 finished with value: 0.6223497374051741 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:33,292] Trial 42 finished with value: 0.6102898268819297 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:35,695] Trial 43 finished with value: 0.6081015366660182 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:38,080] Trial 44 finished with value: 0.5671318809570122 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:40,482] Trial 45 finished with value: 0.5669373662711534 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:42,486] Trial 46 finished with value: 0.5645302470336511 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:44,116] Trial 47 finished with value: 0.5931725345263567 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 64}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:45,103] Trial 48 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 16, 'hidden_size': 112}. Best is trial 22 with value: 0.6295954094534137.
# [I 2024-05-07 11:06:47,093] Trial 49 finished with value: 0.5975491149581794 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 128}. Best is trial 22 with value: 0.6295954094534137.

# %%
best_params_MeDa_resampled
# Out:
# {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}

# %% [markdown]
# #### TF-IDF

# %% [markdown]
# ##### A prediction every day

# %%
# %%capture

best_params_tfidf = LSTM_hyperparametersearch(X_tfidfvect_train_tensor, 
                                            y_tfidfvect_train_tensor, 
                                            n_notes_train, 
                                            X_tfidfvect_test_tensor, 
                                            y_tfidfvect_test_tensor, 
                                            n_notes_test, 
                                            resampled = False)
# Out:
# [I 2024-05-07 11:06:47,459] A new study created in memory with name: no-name-3f6fd750-54b0-4957-8e3e-4feb959adabc
# [I 2024-05-07 11:07:13,214] Trial 0 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 0 with value: 0.5.
# [I 2024-05-07 11:08:12,214] Trial 1 finished with value: 0.5442427312020128 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 48}. Best is trial 1 with value: 0.5442427312020128.
# [I 2024-05-07 11:09:07,611] Trial 2 finished with value: 0.5652595578274171 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 96}. Best is trial 2 with value: 0.5652595578274171.
# [I 2024-05-07 11:10:09,231] Trial 3 finished with value: 0.5740291194441624 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 128}. Best is trial 3 with value: 0.5740291194441624.
# [I 2024-05-07 11:11:09,152] Trial 4 finished with value: 0.5860170069810657 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 112}. Best is trial 4 with value: 0.5860170069810657.
# [I 2024-05-07 11:11:38,995] Trial 5 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 32}. Best is trial 4 with value: 0.5860170069810657.
# [I 2024-05-07 11:12:03,860] Trial 6 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 48, 'hidden_size': 80}. Best is trial 4 with value: 0.5860170069810657.
# [I 2024-05-07 11:12:29,633] Trial 7 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 32}. Best is trial 4 with value: 0.5860170069810657.
# [I 2024-05-07 11:13:00,766] Trial 8 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 16, 'hidden_size': 112}. Best is trial 4 with value: 0.5860170069810657.
# [I 2024-05-07 11:14:01,358] Trial 9 finished with value: 0.5917932224201796 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 112}. Best is trial 9 with value: 0.5917932224201796.
# [I 2024-05-07 11:15:01,594] Trial 10 finished with value: 0.5824645582532052 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 64}. Best is trial 9 with value: 0.5917932224201796.
# [I 2024-05-07 11:16:02,431] Trial 11 finished with value: 0.5885613233420016 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 128}. Best is trial 9 with value: 0.5917932224201796.
# [I 2024-05-07 11:17:02,858] Trial 12 finished with value: 0.5650805037017536 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 128}. Best is trial 9 with value: 0.5917932224201796.
# [I 2024-05-07 11:18:04,849] Trial 13 finished with value: 0.573481544781567 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 128}. Best is trial 9 with value: 0.5917932224201796.
# [I 2024-05-07 11:19:05,006] Trial 14 finished with value: 0.5677304303881068 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 112}. Best is trial 9 with value: 0.5917932224201796.
# [I 2024-05-07 11:20:05,774] Trial 15 finished with value: 0.6001163572916306 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 96}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:21:06,361] Trial 16 finished with value: 0.575069046468915 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:22:12,361] Trial 17 finished with value: 0.5214409413301174 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 96}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:22:37,468] Trial 18 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 32, 'hidden_size': 64}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:23:38,367] Trial 19 finished with value: 0.5826017773027792 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 96}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:24:39,578] Trial 20 finished with value: 0.5965704162422731 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:25:40,957] Trial 21 finished with value: 0.5820079051559779 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:26:42,638] Trial 22 finished with value: 0.5731608091982132 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 64}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:27:44,171] Trial 23 finished with value: 0.59946837844642 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 112}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:28:45,275] Trial 24 finished with value: 0.5985671579406135 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:29:46,999] Trial 25 finished with value: 0.5756521344627689 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:30:48,916] Trial 26 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 64, 'hidden_size': 112}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:31:25,987] Trial 27 finished with value: 0.5038904761426646 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 64}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:31:50,928] Trial 28 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 48, 'hidden_size': 96}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:32:16,459] Trial 29 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 48}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:33:18,317] Trial 30 finished with value: 0.5646831634457377 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:34:19,855] Trial 31 finished with value: 0.576771455165256 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 15 with value: 0.6001163572916306.
# [I 2024-05-07 11:35:21,796] Trial 32 finished with value: 0.6119023208612746 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:36:23,713] Trial 33 finished with value: 0.5956902062413472 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:37:25,455] Trial 34 finished with value: 0.5603892112358975 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 80}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:38:13,704] Trial 35 finished with value: 0.5927050411452621 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 48}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:39:15,817] Trial 36 finished with value: 0.5915344027494385 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 112}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:40:15,260] Trial 37 finished with value: 0.5782085365123528 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 96}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:41:03,167] Trial 38 finished with value: 0.5858719787172882 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 80}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:41:28,780] Trial 39 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 64}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:41:53,718] Trial 40 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 48, 'hidden_size': 112}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:42:55,434] Trial 41 finished with value: 0.5999962441398354 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:43:57,051] Trial 42 finished with value: 0.605282896221865 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:44:58,887] Trial 43 finished with value: 0.5978109656985844 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:46:00,358] Trial 44 finished with value: 0.5975945389049473 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 64}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:47:02,044] Trial 45 finished with value: 0.5957430114040558 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:48:03,709] Trial 46 finished with value: 0.5842829895605681 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 112}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:49:03,876] Trial 47 finished with value: 0.587984557092979 and parameters: {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:50:03,574] Trial 48 finished with value: 0.6060376009945221 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 96}. Best is trial 32 with value: 0.6119023208612746.
# [I 2024-05-07 11:50:28,590] Trial 49 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 48, 'hidden_size': 80}. Best is trial 32 with value: 0.6119023208612746.

# %%
best_params_tfidf
# Out:
# {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}

# %% [markdown]
# ##### One prediction per patient

# %%
# %%capture

best_params_tfidf_resampled = LSTM_hyperparametersearch(X_tfidfvect_train_tensor_resampled, 
                                                        y_tfidfvect_train_tensor_resampled, 
                                                        n_notes_train_resampled, 
                                                        X_tfidfvect_test_tensor_resampled, 
                                                        y_tfidfvect_test_tensor_resampled, 
                                                        n_notes_test_resampled, 
                                                        resampled = True)
# Out:
# [I 2024-05-07 11:50:28,994] A new study created in memory with name: no-name-313fa1cd-0606-4f04-80cc-4f4387a22235
# [I 2024-05-07 11:50:29,968] Trial 0 finished with value: 0.5 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 80}. Best is trial 0 with value: 0.5.
# [I 2024-05-07 11:50:30,794] Trial 1 finished with value: 0.4941402450885042 and parameters: {'learning_rate': 0.1, 'batch_size': 32, 'hidden_size': 128}. Best is trial 0 with value: 0.5.
# [I 2024-05-07 11:50:32,019] Trial 2 finished with value: 0.5543911690332619 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 128}. Best is trial 2 with value: 0.5543911690332619.
# [I 2024-05-07 11:50:33,888] Trial 3 finished with value: 0.5682746547364326 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 32}. Best is trial 3 with value: 0.5682746547364326.
# [I 2024-05-07 11:50:35,808] Trial 4 finished with value: 0.556482201906244 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 64}. Best is trial 3 with value: 0.5682746547364326.
# [I 2024-05-07 11:50:37,747] Trial 5 finished with value: 0.523487648317448 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 32}. Best is trial 3 with value: 0.5682746547364326.
# [I 2024-05-07 11:50:38,721] Trial 6 finished with value: 0.5 and parameters: {'learning_rate': 0.001, 'batch_size': 16, 'hidden_size': 112}. Best is trial 3 with value: 0.5682746547364326.
# [I 2024-05-07 11:50:40,658] Trial 7 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 48}. Best is trial 3 with value: 0.5682746547364326.
# [I 2024-05-07 11:50:42,590] Trial 8 finished with value: 0.5240955067107567 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 32}. Best is trial 3 with value: 0.5682746547364326.
# [I 2024-05-07 11:50:44,333] Trial 9 finished with value: 0.5597160085586461 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 112}. Best is trial 3 with value: 0.5682746547364326.
# [I 2024-05-07 11:50:46,333] Trial 10 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 48, 'hidden_size': 64}. Best is trial 3 with value: 0.5682746547364326.
# [I 2024-05-07 11:50:48,264] Trial 11 finished with value: 0.5101877066718536 and parameters: {'learning_rate': 0.01, 'batch_size': 32, 'hidden_size': 96}. Best is trial 3 with value: 0.5682746547364326.
# [I 2024-05-07 11:50:50,147] Trial 12 finished with value: 0.5901089282240809 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 96}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:50:52,022] Trial 13 finished with value: 0.571581404396032 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 80}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:50:53,178] Trial 14 finished with value: 0.530830577708617 and parameters: {'learning_rate': 0.1, 'batch_size': 48, 'hidden_size': 80}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:50:55,064] Trial 15 finished with value: 0.5281073721065941 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 96}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:50:57,023] Trial 16 finished with value: 0.5697578292161058 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 96}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:50:58,904] Trial 17 finished with value: 0.56669422291383 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 64}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:50:59,727] Trial 18 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 32, 'hidden_size': 112}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:01,676] Trial 19 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 80}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:03,557] Trial 20 finished with value: 0.5545613693833884 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 80}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:05,501] Trial 21 finished with value: 0.5834711145691499 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 96}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:07,449] Trial 22 finished with value: 0.5244115930752772 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 96}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:09,326] Trial 23 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 96}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:11,283] Trial 24 finished with value: 0.5549017700836413 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:13,159] Trial 25 finished with value: 0.5667914802567594 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 64}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:15,104] Trial 26 finished with value: 0.5392676522077416 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 96}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:16,079] Trial 27 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 48, 'hidden_size': 48}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:17,995] Trial 28 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 32, 'hidden_size': 80}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:18,972] Trial 29 finished with value: 0.5 and parameters: {'learning_rate': 0.001, 'batch_size': 48, 'hidden_size': 80}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:20,936] Trial 30 finished with value: 0.5754230694417428 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}. Best is trial 12 with value: 0.5901089282240809.
# [I 2024-05-07 11:51:22,899] Trial 31 finished with value: 0.6015609803540166 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:24,863] Trial 32 finished with value: 0.5145399727679439 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 128}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:26,827] Trial 33 finished with value: 0.5860970628282435 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:28,802] Trial 34 finished with value: 0.5381248784283214 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 128}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:30,770] Trial 35 finished with value: 0.5305388056798288 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:31,724] Trial 36 finished with value: 0.5 and parameters: {'learning_rate': 0.1, 'batch_size': 64, 'hidden_size': 128}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:32,706] Trial 37 finished with value: 0.5 and parameters: {'learning_rate': 0.01, 'batch_size': 16, 'hidden_size': 112}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:33,723] Trial 38 finished with value: 0.5 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:35,686] Trial 39 finished with value: 0.5611019256953901 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:37,656] Trial 40 finished with value: 0.49338650068080137 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 128}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:39,618] Trial 41 finished with value: 0.5738669519548726 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}. Best is trial 31 with value: 0.6015609803540166.
# [I 2024-05-07 11:51:41,577] Trial 42 finished with value: 0.6034818128768722 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}. Best is trial 42 with value: 0.6034818128768722.
# [I 2024-05-07 11:51:43,532] Trial 43 finished with value: 0.5902791285742074 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 96}. Best is trial 42 with value: 0.6034818128768722.
# [I 2024-05-07 11:51:45,496] Trial 44 finished with value: 0.5 and parameters: {'learning_rate': 0.0001, 'batch_size': 64, 'hidden_size': 112}. Best is trial 42 with value: 0.6034818128768722.
# [I 2024-05-07 11:51:46,708] Trial 45 finished with value: 0.559983466251702 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 128}. Best is trial 42 with value: 0.6034818128768722.
# [I 2024-05-07 11:51:47,722] Trial 46 finished with value: 0.5 and parameters: {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 96}. Best is trial 42 with value: 0.6034818128768722.
# [I 2024-05-07 11:51:49,614] Trial 47 finished with value: 0.5853919470920055 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 96}. Best is trial 42 with value: 0.6034818128768722.
# [I 2024-05-07 11:51:51,579] Trial 48 finished with value: 0.549844388251313 and parameters: {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}. Best is trial 42 with value: 0.6034818128768722.
# [I 2024-05-07 11:51:53,497] Trial 49 finished with value: 0.5723837774751993 and parameters: {'learning_rate': 0.01, 'batch_size': 48, 'hidden_size': 128}. Best is trial 42 with value: 0.6034818128768722.

# %%
best_params_tfidf_resampled
# Out:
# {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}

# %%
print(best_params_sentence)
print(best_params_MeDa)
print(best_params_tfidf)

print(best_params_sentence_resampled)
print(best_params_MeDa_resampled)
print(best_params_tfidf_resampled)
# Out:
# {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}
# {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}
# {'learning_rate': 0.001, 'batch_size': 64, 'hidden_size': 80}
# {'learning_rate': 0.001, 'batch_size': 32, 'hidden_size': 80}
# {'learning_rate': 0.0001, 'batch_size': 16, 'hidden_size': 128}
# {'learning_rate': 0.01, 'batch_size': 64, 'hidden_size': 112}

# %% [markdown]
# ## Model run

# %%
from LSTM_pipeline import LSTM_evaluation

learning_rate = 0.0001 
batch_size = 16 
hidden_size = 128

predictions = LSTM_evaluation(X_sentence_train_tensor, 
                            y_sentence_train_tensor, 
                            n_notes_train, 
                            X_sentence_test_tensor, 
                            y_sentence_test_tensor, 
                            n_notes_test, 
                            learning_rate, 
                            batch_size, 
                            hidden_size, 
                            resampled = False)
# Out:
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Epoch: 0, loss: 0.02229
# Epoch: 2, loss: 0.02331
# Early stopping
# Average Test Loss: 0.0025
# 1
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.41      0.58      9241
#          1.0       0.04      0.74      0.07       291
#
#     accuracy                           0.42      9532
#    macro avg       0.51      0.57      0.32      9532
# weighted avg       0.95      0.42      0.56      9532
#
# True Positives: 216. False Positives: 5477. True negatives: 3764. False negatives: 75.
# Accuracy: 41.75%
# Precision = 0.036030871103855555
# Recall = 0.7422680412371134
# F1 score = 0.07219251336898395
# ROC-AUC score = 0.5747916334310229

# %%
learning_rate = 0.001 
batch_size = 32
hidden_size = 80

predictions = LSTM_evaluation(X_MeDa_train_tensor, 
                            y_MeDa_train_tensor, 
                            n_notes_train,
                            X_MeDa_test_tensor, 
                            y_MeDa_test_tensor, 
                            n_notes_test, 
                            learning_rate, 
                            batch_size, 
                            hidden_size, 
                            resampled = False)
# Out:
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Epoch: 0, loss: 0.02259
# Epoch: 2, loss: 0.02399
# Epoch: 4, loss: 0.01789
# Epoch: 6, loss: 0.00915
# Epoch: 8, loss: 0.00995
# Early stopping
# Average Test Loss: 0.0014
# 1
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.61      0.75      9241
#          1.0       0.04      0.51      0.07       291
#
#     accuracy                           0.61      9532
#    macro avg       0.51      0.56      0.41      9532
# weighted avg       0.95      0.61      0.73      9532
#
# True Positives: 148. False Positives: 3572. True negatives: 5669. False negatives: 143.
# Accuracy: 61.03%
# Precision = 0.03523636638459221
# Recall = 0.5085910652920962
# F1 score = 0.0737970580902518
# ROC-AUC score = 0.5610264059281604

# %%
learning_rate = 0.001 
batch_size = 64
hidden_size = 80

predictions = LSTM_evaluation(X_tfidfvect_train_tensor, 
                            y_tfidfvect_train_tensor, 
                            n_notes_train, 
                            X_tfidfvect_test_tensor,
                            y_tfidfvect_test_tensor, 
                            n_notes_test, 
                            learning_rate, 
                            batch_size, 
                            hidden_size, 
                            resampled = False)
# Out:
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Epoch: 0, loss: 0.02032
# Epoch: 2, loss: 0.01688
# Epoch: 4, loss: 0.01429
# Epoch: 6, loss: 0.01192
# Epoch: 8, loss: 0.01240
# Epoch: 10, loss: 0.01210
# Early stopping
# Average Test Loss: 0.0010
# 1
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.65      0.78      9241
#          1.0       0.04      0.53      0.08       291
#
#     accuracy                           0.64      9532
#    macro avg       0.51      0.59      0.43      9532
# weighted avg       0.95      0.64      0.76      9532
#
# True Positives: 153. False Positives: 3260. True negatives: 5981. False negatives: 138.
# Accuracy: 64.35%
# Precision = 0.038047223778463375
# Recall = 0.5257731958762887
# F1 score = 0.0826133909287257
# ROC-AUC score = 0.5864987611239467

# %%
learning_rate = 0.001 
batch_size = 32
hidden_size = 80

predictions = LSTM_evaluation(X_sentence_train_tensor_resampled, 
                            y_sentence_train_tensor_resampled, 
                            n_notes_train_resampled,
                            X_sentence_test_tensor_resampled, 
                            y_sentence_test_tensor_resampled, 
                            n_notes_test_resampled, 
                            learning_rate, 
                            batch_size, 
                            hidden_size, 
                            resampled = True)
# Out:
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Epoch: 0, loss: 0.32304
# Epoch: 2, loss: 0.26972
# Epoch: 4, loss: 0.20981
# Epoch: 6, loss: 0.16020
# Epoch: 8, loss: 0.13980
# Epoch: 10, loss: 0.14769
# Early stopping
# Average Test Loss: 0.0107
# 1
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.47      0.58       212
#          1.0       0.37      0.68      0.48        97
#
#     accuracy                           0.53       309
#    macro avg       0.57      0.57      0.53       309
# weighted avg       0.64      0.53      0.55       309
#
# True Positives: 66. False Positives: 113. True negatives: 99. False negatives: 31.
# Accuracy: 53.40%
# Precision = 0.3512019290359461
# Recall = 0.6804123711340206
# F1 score = 0.4782608695652174
# ROC-AUC score = 0.5736967516047462

# %%
learning_rate = 0.0001 
batch_size = 16 
hidden_size = 128

predictions = LSTM_evaluation(X_MeDa_train_tensor_resampled, 
                            y_MeDa_train_tensor_resampled, 
                            n_notes_train_resampled, 
                            X_MeDa_test_tensor_resampled, 
                            y_MeDa_test_tensor_resampled, 
                            n_notes_test_resampled, 
                            learning_rate, 
                            batch_size, 
                            hidden_size, 
                            resampled = True)
# Out:
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Epoch: 0, loss: 0.32134
# Epoch: 2, loss: 0.30117
# Epoch: 4, loss: 0.26097
# Epoch: 6, loss: 0.22556
# Epoch: 8, loss: 0.20144
# Epoch: 10, loss: 0.16869
# Epoch: 12, loss: 0.13017
# Epoch: 14, loss: 0.12647
# Epoch: 16, loss: 0.11871
# Epoch: 18, loss: 0.11095
# Epoch: 20, loss: 0.10067
# Epoch: 22, loss: 0.09892
# Epoch: 24, loss: 0.09471
# Early stopping
# Average Test Loss: 0.0264
# 1
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.70      0.72       212
#          1.0       0.43      0.49      0.46        97
#
#     accuracy                           0.63       309
#    macro avg       0.59      0.60      0.59       309
# weighted avg       0.65      0.63      0.64       309
#
# True Positives: 48. False Positives: 64. True negatives: 148. False negatives: 49.
# Accuracy: 63.43%
# Precision = 0.3706526349905391
# Recall = 0.4948453608247423
# F1 score = 0.4593301435406698
# ROC-AUC score = 0.5964792841859561

# %%
learning_rate = 0.01 
batch_size = 64
hidden_size = 112 

predictions = LSTM_evaluation(X_tfidfvect_train_tensor_resampled, 
                            y_tfidfvect_train_tensor_resampled, 
                            n_notes_train_resampled, 
                            X_tfidfvect_test_tensor_resampled, 
                            y_tfidfvect_test_tensor_resampled, 
                            n_notes_test_resampled, 
                            learning_rate, 
                            batch_size, 
                            hidden_size, 
                            resampled = True)
# Out:
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Epoch: 0, loss: 0.32680
# Epoch: 2, loss: 0.27442
# Epoch: 4, loss: 0.15883
# Epoch: 6, loss: 0.14540
# Epoch: 8, loss: 0.07781
# Epoch: 10, loss: 0.04450
# Epoch: 12, loss: 0.19380
# Epoch: 14, loss: 0.00689
# Epoch: 16, loss: 0.00610
# Epoch: 18, loss: 0.00465
# Early stopping
# Average Test Loss: 0.0193
# 1
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.67      0.67       212
#          1.0       0.28      0.28      0.28        97
#
#     accuracy                           0.55       309
#    macro avg       0.47      0.47      0.47       309
# weighted avg       0.55      0.55      0.55       309
#
# True Positives: 27. False Positives: 70. True negatives: 142. False negatives: 70.
# Accuracy: 54.69%
# Precision = 0.3040162262875076
# Recall = 0.27835051546391754
# F1 score = 0.27835051546391754
# ROC-AUC score = 0.47408091810931724

# %% [markdown]
# #### Evaluting the resampled model on all data

# %%
learning_rate = 0.001 
batch_size = 32
hidden_size = 80

predictions = LSTM_evaluation(X_sentence_train_tensor_resampled, 
                            y_sentence_train_tensor_resampled, 
                            n_notes_train_resampled,
                            X_sentence_test_tensor, 
                            y_sentence_test_tensor, 
                            n_notes_test, 
                            learning_rate, 
                            batch_size, 
                            hidden_size, 
                            resampled = True)
# Out:
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Epoch: 0, loss: 0.32506
# Epoch: 2, loss: 0.27171
# Epoch: 4, loss: 0.22728
# Epoch: 6, loss: 0.18920
# Epoch: 8, loss: 0.14021
# Epoch: 10, loss: 0.11673
# Epoch: 12, loss: 0.13688
# Epoch: 14, loss: 0.11609
# Early stopping
# Average Test Loss: 0.0088
# 1
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.07      0.13      9241
#          1.0       0.03      0.89      0.06       291
#
#     accuracy                           0.09      9532
#    macro avg       0.49      0.48      0.09      9532
# weighted avg       0.92      0.09      0.13      9532
#
# True Positives: 259. False Positives: 8598. True negatives: 643. False negatives: 32.
# Accuracy: 9.46%
# Precision = 0.029383860127319764
# Recall = 0.8900343642611683
# F1 score = 0.05662439877568867
# ROC-AUC score = 0.47980778920774025

# %%
learning_rate = 0.0001 
batch_size = 16 
hidden_size = 128

predictions = LSTM_evaluation(X_MeDa_train_tensor_resampled, 
                            y_MeDa_train_tensor_resampled, 
                            n_notes_train_resampled, 
                            X_MeDa_test_tensor, 
                            y_MeDa_test_tensor, 
                            n_notes_test, 
                            learning_rate, 
                            batch_size, 
                            hidden_size, 
                            resampled = True)
# Out:
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Epoch: 0, loss: 0.32145
# Epoch: 2, loss: 0.29499
# Epoch: 4, loss: 0.24915
# Epoch: 6, loss: 0.21006
# Epoch: 8, loss: 0.18495
# Epoch: 10, loss: 0.16306
# Epoch: 12, loss: 0.12244
# Epoch: 14, loss: 0.09162
# Epoch: 16, loss: 0.07028
# Epoch: 18, loss: 0.03817
# Epoch: 20, loss: 0.01946
# Epoch: 22, loss: 0.01659
# Epoch: 24, loss: 0.01539
# Epoch: 26, loss: 0.06759
# Early stopping
# Average Test Loss: 0.0100
# 1
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.93      0.95      9241
#          1.0       0.06      0.14      0.08       291
#
#     accuracy                           0.91      9532
#    macro avg       0.52      0.53      0.52      9532
# weighted avg       0.94      0.91      0.92      9532
#
# True Positives: 40. False Positives: 638. True negatives: 8603. False negatives: 251.
# Accuracy: 90.67%
# Precision = 0.034441914333140096
# Recall = 0.13745704467353953
# F1 score = 0.08255933952528381
# ROC-AUC score = 0.5342084487516598

# %%
from LSTM_pipeline import LSTM_evaluation

from tfidf import tf_idf

df_tfidfvect_train_resampled_new, df_tfidfvect_test_new = tf_idf(predictor_dict_train_resampled["df_SFI_text"], predictor_dict_test["df_SFI_text"], min_df = 30, max_df = 0.6, max_features=400, ngram_range = (1, 2))
# Out:
# e:\Projekter\RHN\linapd\tfidf.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   X_train_SFI['note'] = X_train_SFI['note'].str.replace('\d+', '')
# e:\Projekter\RHN\linapd\tfidf.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   X_test_SFI['note'] = X_test_SFI['note'].str.replace('\d+', '')
# Tokens ['aff' 'aften' 'av' 'bad' 'behov' 'ble' 'ble samt' 'ble skiftet' 'bleen'
#  'bleen våd' 'bleskift' 'blære' 'blæren' 'blærescannet' 'bukser'
#  'bundskiftet' 'bækken' 'bækkenstol' 'ca' 'ca ml' 'dag' 'dv'
#  'efterfølgende' 'evt' 'faldet' 'fik' 'fint' 'forbindelse' 'forsøgt'
#  'fortæller' 'fået' 'får' 'føler' 'gang' 'gange' 'gerne' 'givet' 'godt'
#  'gået' 'går' 'haft' 'hjælp' 'inden' 'kad' 'kalder' 'kateter' 'kl' 'klar'
#  'klar urin' 'kolbe' 'kolbe ml' 'kolben' 'komme' 'kommet' 'konc'
#  'koncentreret' 'lade' 'lade vandet' 'let' 'løbet' 'ml' 'ml klar'
#  'ml kolbe' 'ml urin' 'morgen' 'mærke' 'nat' 'natten' 'når' 'obs' 'pga'
#  'pose' 'pose tømt' 'posen' 'pt' 'påsat' 'påsat uridom' 'resultat'
#  'ringer' 'samt' 'sat' 'scannet' 'se' 'seng' 'sengen' 'sidste' 'siger'
#  'sik' 'skift' 'skift våd' 'skiftet' 'skiftet våd' 'spontan' 'stikbækken'
#  'stix' 'stor' 'stor vandl' 'stor vandladning' 'str' 'stuen' 'tages'
#  'taget' 'time' 'tisse' 'tisser' 'tisset' 'toilet' 'toiletbesøg'
#  'toilettet' 'trang' 'tung' 'tung ble' 'tung våd' 'tømt' 'tømt ml' 'tør'
#  'tør ble' 'uheld' 'uridom' 'uridom nat' 'uridom påsat' 'uridomet' 'urin'
#  'urinen' 'urinpose' 'ut' 'uvi' 'vagten' 'vandet' 'vandl' 'vandl ble'
#  'vandl bækken' 'vandl kolbe' 'vandl toilet' 'vandl toilettet'
#  'vandladning' 'vandladning ble' 'vandladning bækken'
#  'vandladning bækkenstol' 'vandladning kolbe' 'vandladning stikbækken'
#  'vandladning toilet' 'vandladning toilettet' 'vandladninger'
#  'vandladningstrang' 'vl' 'våd' 'våd ble' 'våde' 'wc' 'ønsker']

# %%
from create_tensors import tensors
import torch

maximum_notes = 38

#Test
X_tfidfvect_test_tensor_new, y_tfidfvect_test_tensor_new, X_structured_test_tensor_new, n_notes_test_new = tensors(df_tfidfvect_test_new, y_test_df, df_admissions_test, maximum_notes, predictor_dict_test) 
torch.save(X_tfidfvect_test_tensor_new, 'data/tensors/X_tfidfvect_test_tensor_4_days_new.pt')
torch.save(y_tfidfvect_test_tensor_new, 'data/tensors/y_tfidfvect_test_tensor_4_days_new.pt')
# Out:
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# ...
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)
# e:\Projekter\RHN\linapd\create_tensors.py:136: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   subset = subset.append(pd.Series(0, index=subset.columns), ignore_index=True)

# %%
#Test
X_tfidfvect_test_tensor_new = torch.load("data/tensors/X_tfidfvect_test_tensor_4_days_new.pt", map_location=torch.device('cuda'))
y_tfidfvect_test_tensor_new = torch.load("data/tensors/y_tfidfvect_test_tensor_4_days_new.pt", map_location=torch.device('cuda'))

# %%
learning_rate = 0.01 
batch_size = 64
hidden_size = 112 

predictions = LSTM_evaluation(X_tfidfvect_train_tensor_resampled, 
                            y_tfidfvect_train_tensor_resampled, 
                            n_notes_train_resampled, 
                            X_tfidfvect_test_tensor_new, 
                            y_tfidfvect_test_tensor_new, 
                            n_notes_test_new, 
                            learning_rate, 
                            batch_size, 
                            hidden_size, 
                            resampled = True)
# Out:
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# cuda:0
# Epoch: 0, loss: 0.32619
# Epoch: 2, loss: 0.21568
# Epoch: 4, loss: 0.22051
# Epoch: 6, loss: 0.16137
# Epoch: 8, loss: 0.08381
# Epoch: 10, loss: 0.04513
# Epoch: 12, loss: 0.01914
# Epoch: 14, loss: 0.00656
# Epoch: 16, loss: 0.00508
# Epoch: 18, loss: 0.00275
# Epoch: 20, loss: 0.00457
# Early stopping
# Average Test Loss: 0.0062
# 1
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.77      0.86      9241
#          1.0       0.04      0.29      0.07       291
#
#     accuracy                           0.75      9532
#    macro avg       0.50      0.53      0.46      9532
# weighted avg       0.94      0.75      0.83      9532
#
# True Positives: 83. False Positives: 2142. True negatives: 7099. False negatives: 208.
# Accuracy: 75.35%
# Precision = 0.032461026781186876
# Recall = 0.2852233676975945
# F1 score = 0.06597774244833068
# ROC-AUC score = 0.5267151358561557
